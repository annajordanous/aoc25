# %% [markdown]
# --- Day 1: Secret Entrance ---
# The Elves have good news and bad news.
#
# The good news is that they've discovered project management! This has given them the tools they need to prevent their usual Christmas emergency. For example, they now know that the North Pole decorations need to be finished soon so that other critical tasks can start on time.
#
# The bad news is that they've realized they have a different emergency: according to their resource planning, none of them have any time left to decorate the North Pole!
#
# To save Christmas, the Elves need you to finish decorating the North Pole by December 12th.
#
# Collect stars by solving puzzles. Two puzzles will be made available on each day; the second puzzle is unlocked when you complete the first. Each puzzle grants one star. Good luck!

# %% [markdown]
# You arrive at the secret entrance to the North Pole base ready to start decorating. Unfortunately, the password seems to have been changed, so you can't get in. A document taped to the wall helpfully explains:
#
# "Due to new security protocols, the password is locked in the safe below. Please see the attached document for the new combination."

# %%
combinations = []

with open('day01.txt', 'r') as file:
    for line in file:
        combinations.append(line.strip())

print(len(combinations))
print(combinations[0:10])
print(type(combinations))
# Out:
# 4577
# ['R1', 'R25', 'R50', 'R10', 'L20', 'L14', 'L26', 'L5', 'R19', 'R35']
# <class 'list'>

# %% [markdown]
# The safe has a dial with only an arrow on it; around the dial are the numbers 0 through 99 in order. As you turn the dial, it makes a small click noise as it reaches each number.
#
# The attached document (your puzzle input) contains a sequence of rotations, one per line, which tell you how to open the safe. A rotation starts with an L or R which indicates whether the rotation should be to the left (toward lower numbers) or to the right (toward higher numbers). Then, the rotation has a distance value which indicates how many clicks the dial should be rotated in that direction.
#
# So, if the dial were pointing at 11, a rotation of R8 would cause the dial to point at 19. After that, a rotation of L19 would cause it to point at 0.
#
# Because the dial is a circle, turning the dial left from 0 one click makes it point at 99. Similarly, turning the dial right from 99 one click makes it point at 0.
#
# So, if the dial were pointing at 5, a rotation of L10 would cause it to point at 95. After that, a rotation of R5 could cause it to point at 0.
#
# The dial starts by pointing at 50.

# %%
current_point = 50
# print(101 %100 )

def make_rotation(rotation, current_point):
    print("Current point ", str(current_point), " Rotation ", rotation)
    right = True if rotation[0]=="R" else False
    distance = int(rotation[1:])
    current_point = (current_point + distance)%100 if right else (current_point - distance)%100
    print("Current point now = "+str(current_point))
    return current_point

current_point = make_rotation("L11", current_point)
# Out:
# Current point  50  Rotation  L11
# Current point now = 39

# %% [markdown]
# You could follow the instructions, but your recent required official North Pole secret entrance security training seminar taught you that the safe is actually a decoy. The actual password is the number of times the dial is left pointing at 0 after any rotation in the sequence.
#
# For example, suppose the attached document contained the following rotations:
#
# L68
# L30
# R48
# L5
# R60
# L55
# L1
# L99
# R14
# L82
# Following these rotations would cause the dial to move as follows:
#
# The dial starts by pointing at 50.
# The dial is rotated L68 to point at 82.
# The dial is rotated L30 to point at 52.
# The dial is rotated R48 to point at 0.
# The dial is rotated L5 to point at 95.
# The dial is rotated R60 to point at 55.
# The dial is rotated L55 to point at 0.
# The dial is rotated L1 to point at 99.
# The dial is rotated L99 to point at 0.
# The dial is rotated R14 to point at 14.
# The dial is rotated L82 to point at 32.
# Because the dial points at 0 a total of three times during this process, the password in this example is 3.

# %%
def get_password(data):
    current_point = 50
    count=0
    for d in data:
        current_point = make_rotation(d, current_point)
        if current_point==0:
            count +=1
    return count

test_data = ["L68", "L30", "R48", "L5", "R60", "L55", "L1", "L99", "R14", "L82"]
print(get_password(test_data))
# Out:
# Current point  50  Rotation  L68
# Current point now = 82
# Current point  82  Rotation  L30
# Current point now = 52
# Current point  52  Rotation  R48
# Current point now = 0
# Current point  0  Rotation  L5
# Current point now = 95
# Current point  95  Rotation  R60
# Current point now = 55
# Current point  55  Rotation  L55
# Current point now = 0
# Current point  0  Rotation  L1
# Current point now = 99
# Current point  99  Rotation  L99
# Current point now = 0
# Current point  0  Rotation  R14
# Current point now = 14
# Current point  14  Rotation  L82
# Current point now = 32
# 3

# %% [markdown]
# Analyze the rotations in your attached document. What's the actual password to open the door?

# %%
print(get_password(combinations))
# Out:
# Current point  50  Rotation  R1
# Current point now = 51
# Current point  51  Rotation  R25
# Current point now = 76
# Current point  76  Rotation  R50
# Current point now = 26
# Current point  26  Rotation  R10
# Current point now = 36
# Current point  36  Rotation  L20
# Current point now = 16
# Current point  16  Rotation  L14
# Current point now = 2
# Current point  2  Rotation  L26
# Current point now = 76
# Current point  76  Rotation  L5
# Current point now = 71
# Current point  71  Rotation  R19
# Current point now = 90
# Current point  90  Rotation  R35
# Current point now = 25
# Current point  25  Rotation  R36
# Current point now = 61
# Current point  61  Rotation  R1
# Current point now = 62
# Current point  62  Rotation  L50
# Current point now = 12
# Current point  12  Rotation  L20
# Current point now = 92
# Current point  92  Rotation  L34
# Current point now = 58
# Current point  58  Rotation  L2
# Current point now = 56
# Current point  56  Rotation  L31
# Current point now = 25
# Current point  25  Rotation  L22
# Current point now = 3
# Current point  3  Rotation  L8
# Current point now = 95
# Current point  95  Rotation  L43
# Current point now = 52
# Current point  52  Rotation  R25
# Current point now = 77
# Current point  77  Rotation  L20
# Current point now = 57
# Current point  57  Rotation  L18
# Current point now = 39
# Current point  39  Rotation  L14
# Current point now = 25
# Current point  25  Rotation  R24
# Current point now = 49
# Current point  49  Rotation  L30
# Current point now = 19
# Current point  19  Rotation  L48
# Current point now = 71
# Current point  71  Rotation  L2
# Current point now = 69
# Current point  69  Rotation  L23
# Current point now = 46
# Current point  46  Rotation  L7
# Current point now = 39
# Current point  39  Rotation  R46
# Current point now = 85
# Current point  85  Rotation  L17
# Current point now = 68
# Current point  68  Rotation  L41
# Current point now = 27
# Current point  27  Rotation  L41
# Current point now = 86
# Current point  86  Rotation  L26
# Current point now = 60
# Current point  60  Rotation  L12
# Current point now = 48
# Current point  48  Rotation  R3
# Current point now = 51
# Current point  51  Rotation  R23
# Current point now = 74
# Current point  74  Rotation  R39
# Current point now = 13
# Current point  13  Rotation  L35
# Current point now = 78
# Current point  78  Rotation  L39
# Current point now = 39
# Current point  39  Rotation  L34
# Current point now = 5
# Current point  5  Rotation  L47
# Current point now = 58
# Current point  58  Rotation  L28
# Current point now = 30
# Current point  30  Rotation  R44
# Current point now = 74
# Current point  74  Rotation  L17
# Current point now = 57
# Current point  57  Rotation  R35
# Current point now = 92
# Current point  92  Rotation  R44
# Current point now = 36
# Current point  36  Rotation  L49
# Current point now = 87
# Current point  87  Rotation  L75
# Current point now = 12
# Current point  12  Rotation  L89
# Current point now = 23
# Current point  23  Rotation  R94
# Current point now = 17
# Current point  17  Rotation  R71
# Current point now = 88
# Current point  88  Rotation  L98
# Current point now = 90
# Current point  90  Rotation  L90
# Current point now = 0
# Current point  0  Rotation  L91
# Current point now = 9
# Current point  9  Rotation  L58
# Current point now = 51
# Current point  51  Rotation  R49
# Current point now = 0
# Current point  0  Rotation  R35
# Current point now = 35
# Current point  35  Rotation  R65
# Current point now = 0
# Current point  0  Rotation  L71
# Current point now = 29
# Current point  29  Rotation  R91
# Current point now = 20
# Current point  20  Rotation  L7
# Current point now = 13
# Current point  13  Rotation  R61
# Current point now = 74
# Current point  74  Rotation  R66
# Current point now = 40
# Current point  40  Rotation  L28
# Current point now = 12
# Current point  12  Rotation  L12
# Current point now = 0
# Current point  0  Rotation  R59
# Current point now = 59
# Current point  59  Rotation  L88
# Current point now = 71
# Current point  71  Rotation  L71
# Current point now = 0
# Current point  0  Rotation  L75
# Current point now = 25
# Current point  25  Rotation  L24
# Current point now = 1
# Current point  1  Rotation  L25
# Current point now = 76
# Current point  76  Rotation  L44
# Current point now = 32
# Current point  32  Rotation  R68
# Current point now = 0
# Current point  0  Rotation  R69
# Current point now = 69
# Current point  69  Rotation  L99
# Current point now = 70
# Current point  70  Rotation  R62
# Current point now = 32
# Current point  32  Rotation  L84
# Current point now = 48
# Current point  48  Rotation  R52
# Current point now = 0
# Current point  0  Rotation  R23
# Current point now = 23
# Current point  23  Rotation  L23
# Current point now = 0
# Current point  0  Rotation  R69
# Current point now = 69
# Current point  69  Rotation  R96
# Current point now = 65
# Current point  65  Rotation  R35
# Current point now = 0
# Current point  0  Rotation  R45
# Current point now = 45
# Current point  45  Rotation  R55
# Current point now = 0
# Current point  0  Rotation  R39
# Current point now = 39
# Current point  39  Rotation  R61
# Current point now = 0
# Current point  0  Rotation  L1
# Current point now = 99
# Current point  99  Rotation  L20
# Current point now = 79
# Current point  79  Rotation  R70
# Current point now = 49
# Current point  49  Rotation  L49
# Current point now = 0
# Current point  0  Rotation  L97
# Current point now = 3
# Current point  3  Rotation  R97
# Current point now = 0
# Current point  0  Rotation  R36
# Current point now = 36
# Current point  36  Rotation  R68
# Current point now = 4
# Current point  4  Rotation  L4
# Current point now = 0
# Current point  0  Rotation  R22
# Current point now = 22
# Current point  22  Rotation  R61
# Current point now = 83
# Current point  83  Rotation  R22
# Current point now = 5
# Current point  5  Rotation  R95
# Current point now = 0
# Current point  0  Rotation  R63
# Current point now = 63
# Current point  63  Rotation  L82
# Current point now = 81
# Current point  81  Rotation  R45
# Current point now = 26
# Current point  26  Rotation  R9
# Current point now = 35
# Current point  35  Rotation  R83
# Current point now = 18
# Current point  18  Rotation  R86
# Current point now = 4
# Current point  4  Rotation  R96
# Current point now = 0
# Current point  0  Rotation  R49
# Current point now = 49
# Current point  49  Rotation  L49
# Current point now = 0
# Current point  0  Rotation  L48
# Current point now = 52
# Current point  52  Rotation  L68
# Current point now = 84
# Current point  84  Rotation  R150
# Current point now = 34
# Current point  34  Rotation  R66
# Current point now = 0
# Current point  0  Rotation  R89
# Current point now = 89
# Current point  89  Rotation  L589
# Current point now = 0
# Current point  0  Rotation  R85
# Current point now = 85
# Current point  85  Rotation  R15
# Current point now = 0
# Current point  0  Rotation  L70
# Current point now = 30
# Current point  30  Rotation  R70
# Current point now = 0
# Current point  0  Rotation  L95
# Current point now = 5
# Current point  5  Rotation  L305
# Current point now = 0
# Current point  0  Rotation  R28
# Current point now = 28
# Current point  28  Rotation  R72
# Current point now = 0
# Current point  0  Rotation  R58
# Current point now = 58
# Current point  58  Rotation  L47
# Current point now = 11
# Current point  11  Rotation  R50
# Current point now = 61
# Current point  61  Rotation  L61
# Current point now = 0
# Current point  0  Rotation  L25
# Current point now = 75
# Current point  75  Rotation  R25
# Current point now = 0
# Current point  0  Rotation  L43
# Current point now = 57
# Current point  57  Rotation  L34
# Current point now = 23
# Current point  23  Rotation  L23
# Current point now = 0
# Current point  0  Rotation  R95
# Current point now = 95
# Current point  95  Rotation  R84
# Current point now = 79
# Current point  79  Rotation  R821
# Current point now = 0
# Current point  0  Rotation  R83
# Current point now = 83
# Current point  83  Rotation  L25
# Current point now = 58
# Current point  58  Rotation  R90
# Current point now = 48
# Current point  48  Rotation  R366
# Current point now = 14
# Current point  14  Rotation  L639
# Current point now = 75
# Current point  75  Rotation  R25
# Current point now = 0
# Current point  0  Rotation  R70
# Current point now = 70
# Current point  70  Rotation  R22
# Current point now = 92
# Current point  92  Rotation  L75
# Current point now = 17
# Current point  17  Rotation  L117
# Current point now = 0
# Current point  0  Rotation  L77
# Current point now = 23
# Current point  23  Rotation  R67
# Current point now = 90
# Current point  90  Rotation  L490
# Current point now = 0
# Current point  0  Rotation  R23
# Current point now = 23
# Current point  23  Rotation  R277
# Current point now = 0
# Current point  0  Rotation  L55
# Current point now = 45
# Current point  45  Rotation  L25
# Current point now = 20
# Current point  20  Rotation  L20
# Current point now = 0
# Current point  0  Rotation  L9
# Current point now = 91
# Current point  91  Rotation  R66
# Current point now = 57
# Current point  57  Rotation  L34
# Current point now = 23
# Current point  23  Rotation  R83
# Current point now = 6
# Current point  6  Rotation  R82
# Current point now = 88
# Current point  88  Rotation  L76
# Current point now = 12
# Current point  12  Rotation  L18
# Current point now = 94
# Current point  94  Rotation  L54
# Current point now = 40
# Current point  40  Rotation  R60
# Current point now = 0
# Current point  0  Rotation  L305
# Current point now = 95
# Current point  95  Rotation  L87
# Current point now = 8
# Current point  8  Rotation  R81
# Current point now = 89
# Current point  89  Rotation  L71
# Current point now = 18
# Current point  18  Rotation  R4
# Current point now = 22
# Current point  22  Rotation  L22
# Current point now = 0
# Current point  0  Rotation  R255
# Current point now = 55
# Current point  55  Rotation  L655
# Current point now = 0
# Current point  0  Rotation  L91
# Current point now = 9
# Current point  9  Rotation  L9
# Current point now = 0
# Current point  0  Rotation  L398
# Current point now = 2
# Current point  2  Rotation  L40
# Current point now = 62
# Current point  62  Rotation  R56
# Current point now = 18
# Current point  18  Rotation  R13
# Current point now = 31
# Current point  31  Rotation  L88
# Current point now = 43
# Current point  43  Rotation  R73
# Current point now = 16
# Current point  16  Rotation  L55
# Current point now = 61
# Current point  61  Rotation  L61
# Current point now = 0
# Current point  0  Rotation  L87
# Current point now = 13
# Current point  13  Rotation  R405
# Current point now = 18
# Current point  18  Rotation  R27
# Current point now = 45
# Current point  45  Rotation  L45
# Current point now = 0
# Current point  0  Rotation  L80
# Current point now = 20
# Current point  20  Rotation  R80
# Current point now = 0
# Current point  0  Rotation  L72
# Current point now = 28
# Current point  28  Rotation  L96
# Current point now = 32
# Current point  32  Rotation  R68
# Current point now = 0
# Current point  0  Rotation  R60
# Current point now = 60
# Current point  60  Rotation  R825
# Current point now = 85
# Current point  85  Rotation  R8
# Current point now = 93
# Current point  93  Rotation  R207
# Current point now = 0
# Current point  0  Rotation  R96
# Current point now = 96
# Current point  96  Rotation  L55
# Current point now = 41
# Current point  41  Rotation  R59
# Current point now = 0
# Current point  0  Rotation  L71
# Current point now = 29
# Current point  29  Rotation  R98
# Current point now = 27
# Current point  27  Rotation  R3
# Current point now = 30
# Current point  30  Rotation  L230
# Current point now = 0
# Current point  0  Rotation  R50
# Current point now = 50
# Current point  50  Rotation  L50
# Current point now = 0
# Current point  0  Rotation  L729
# Current point now = 71
# Current point  71  Rotation  R15
# Current point now = 86
# Current point  86  Rotation  R11
# Current point now = 97
# Current point  97  Rotation  L86
# Current point now = 11
# Current point  11  Rotation  R62
# Current point now = 73
# Current point  73  Rotation  R27
# Current point now = 0
# Current point  0  Rotation  L6
# Current point now = 94
# Current point  94  Rotation  L94
# Current point now = 0
# Current point  0  Rotation  R54
# Current point now = 54
# Current point  54  Rotation  R51
# Current point now = 5
# Current point  5  Rotation  L5
# Current point now = 0
# Current point  0  Rotation  L88
# Current point now = 12
# Current point  12  Rotation  L89
# Current point now = 23
# Current point  23  Rotation  L123
# Current point now = 0
# Current point  0  Rotation  R88
# Current point now = 88
# Current point  88  Rotation  L349
# Current point now = 39
# Current point  39  Rotation  R42
# Current point now = 81
# Current point  81  Rotation  L51
# Current point now = 30
# Current point  30  Rotation  L88
# Current point now = 42
# Current point  42  Rotation  R15
# Current point now = 57
# Current point  57  Rotation  R44
# Current point now = 1
# Current point  1  Rotation  L94
# Current point now = 7
# Current point  7  Rotation  L29
# Current point now = 78
# Current point  78  Rotation  L78
# Current point now = 0
# Current point  0  Rotation  R49
# Current point now = 49
# Current point  49  Rotation  L86
# Current point now = 63
# Current point  63  Rotation  R85
# Current point now = 48
# Current point  48  Rotation  L36
# Current point now = 12
# Current point  12  Rotation  R54
# Current point now = 66
# Current point  66  Rotation  L146
# Current point now = 20
# Current point  20  Rotation  L20
# Current point now = 0
# Current point  0  Rotation  R6
# Current point now = 6
# Current point  6  Rotation  R94
# Current point now = 0
# Current point  0  Rotation  L35
# Current point now = 65
# Current point  65  Rotation  L46
# Current point now = 19
# Current point  19  Rotation  L17
# Current point now = 2
# Current point  2  Rotation  R23
# Current point now = 25
# Current point  25  Rotation  R74
# Current point now = 99
# Current point  99  Rotation  L99
# Current point now = 0
# Current point  0  Rotation  R95
# Current point now = 95
# Current point  95  Rotation  L26
# Current point now = 69
# Current point  69  Rotation  L47
# Current point now = 22
# Current point  22  Rotation  R52
# Current point now = 74
# Current point  74  Rotation  L74
# Current point now = 0
# Current point  0  Rotation  L96
# Current point now = 4
# Current point  4  Rotation  L51
# Current point now = 53
# Current point  53  Rotation  R47
# Current point now = 0
# Current point  0  Rotation  L239
# Current point now = 61
# Current point  61  Rotation  R48
# Current point now = 9
# Current point  9  Rotation  R186
# Current point now = 95
# Current point  95  Rotation  L44
# Current point now = 51
# Current point  51  Rotation  L18
# Current point now = 33
# Current point  33  Rotation  L33
# Current point now = 0
# Current point  0  Rotation  R83
# Current point now = 83
# Current point  83  Rotation  R3
# Current point now = 86
# Current point  86  Rotation  R561
# Current point now = 47
# Current point  47  Rotation  R86
# Current point now = 33
# Current point  33  Rotation  L933
# Current point now = 0
# Current point  0  Rotation  R527
# Current point now = 27
# Current point  27  Rotation  R88
# Current point now = 15
# Current point  15  Rotation  R85
# Current point now = 0
# Current point  0  Rotation  L186
# Current point now = 14
# Current point  14  Rotation  R86
# Current point now = 0
# Current point  0  Rotation  L1
# Current point now = 99
# Current point  99  Rotation  L99
# Current point now = 0
# Current point  0  Rotation  L3
# Current point now = 97
# Current point  97  Rotation  L97
# Current point now = 0
# Current point  0  Rotation  R68
# Current point now = 68
# Current point  68  Rotation  L81
# Current point now = 87
# Current point  87  Rotation  L50
# Current point now = 37
# Current point  37  Rotation  R360
# Current point now = 97
# Current point  97  Rotation  L46
# Current point now = 51
# Current point  51  Rotation  R70
# Current point now = 21
# Current point  21  Rotation  R81
# Current point now = 2
# Current point  2  Rotation  L2
# Current point now = 0
# Current point  0  Rotation  L87
# Current point now = 13
# Current point  13  Rotation  R92
# Current point now = 5
# Current point  5  Rotation  R95
# Current point now = 0
# Current point  0  Rotation  R39
# Current point now = 39
# Current point  39  Rotation  R4
# Current point now = 43
# Current point  43  Rotation  L90
# Current point now = 53
# Current point  53  Rotation  R603
# Current point now = 56
# Current point  56  Rotation  R467
# Current point now = 23
# Current point  23  Rotation  R36
# Current point now = 59
# Current point  59  Rotation  L24
# Current point now = 35
# Current point  35  Rotation  L35
# Current point now = 0
# Current point  0  Rotation  R12
# Current point now = 12
# Current point  12  Rotation  L46
# Current point now = 66
# Current point  66  Rotation  L80
# Current point now = 86
# Current point  86  Rotation  R65
# Current point now = 51
# Current point  51  Rotation  R28
# Current point now = 79
# Current point  79  Rotation  R51
# Current point now = 30
# Current point  30  Rotation  R70
# Current point now = 0
# Current point  0  Rotation  R83
# Current point now = 83
# Current point  83  Rotation  L26
# Current point now = 57
# Current point  57  Rotation  L431
# Current point now = 26
# Current point  26  Rotation  R818
# Current point now = 44
# Current point  44  Rotation  R114
# Current point now = 58
# Current point  58  Rotation  L58
# Current point now = 0
# Current point  0  Rotation  L29
# Current point now = 71
# Current point  71  Rotation  R29
# Current point now = 0
# Current point  0  Rotation  L65
# Current point now = 35
# Current point  35  Rotation  R23
# Current point now = 58
# Current point  58  Rotation  R22
# Current point now = 80
# Current point  80  Rotation  R343
# Current point now = 23
# Current point  23  Rotation  L593
# Current point now = 30
# Current point  30  Rotation  L56
# Current point now = 74
# Current point  74  Rotation  L174
# Current point now = 0
# Current point  0  Rotation  L65
# Current point now = 35
# Current point  35  Rotation  R65
# Current point now = 0
# Current point  0  Rotation  L79
# Current point now = 21
# Current point  21  Rotation  R19
# Current point now = 40
# Current point  40  Rotation  R50
# Current point now = 90
# Current point  90  Rotation  R12
# Current point now = 2
# Current point  2  Rotation  R90
# Current point now = 92
# Current point  92  Rotation  L92
# Current point now = 0
# Current point  0  Rotation  R89
# Current point now = 89
# Current point  89  Rotation  R11
# Current point now = 0
# Current point  0  Rotation  L20
# Current point now = 80
# Current point  80  Rotation  L80
# Current point now = 0
# Current point  0  Rotation  L88
# Current point now = 12
# Current point  12  Rotation  R98
# Current point now = 10
# Current point  10  Rotation  L10
# Current point now = 0
# Current point  0  Rotation  L540
# Current point now = 60
# Current point  60  Rotation  L901
# Current point now = 59
# Current point  59  Rotation  R41
# Current point now = 0
# Current point  0  Rotation  R57
# Current point now = 57
# Current point  57  Rotation  L27
# Current point now = 30
# Current point  30  Rotation  R12
# Current point now = 42
# Current point  42  Rotation  L589
# Current point now = 53
# Current point  53  Rotation  L35
# Current point now = 18
# Current point  18  Rotation  L218
# Current point now = 0
# Current point  0  Rotation  L79
# Current point now = 21
# Current point  21  Rotation  R79
# Current point now = 0
# Current point  0  Rotation  L578
# Current point now = 22
# Current point  22  Rotation  R12
# Current point now = 34
# Current point  34  Rotation  R16
# Current point now = 50
# Current point  50  Rotation  R71
# Current point now = 21
# Current point  21  Rotation  L421
# Current point now = 0
# Current point  0  Rotation  L18
# Current point now = 82
# Current point  82  Rotation  L82
# Current point now = 0
# Current point  0  Rotation  R37
# Current point now = 37
# Current point  37  Rotation  R63
# Current point now = 0
# Current point  0  Rotation  L50
# Current point now = 50
# Current point  50  Rotation  R50
# Current point now = 0
# Current point  0  Rotation  R71
# Current point now = 71
# Current point  71  Rotation  R71
# Current point now = 42
# Current point  42  Rotation  R58
# Current point now = 0
# Current point  0  Rotation  R34
# Current point now = 34
# Current point  34  Rotation  L534
# Current point now = 0
# Current point  0  Rotation  L390
# Current point now = 10
# Current point  10  Rotation  R862
# Current point now = 72
# Current point  72  Rotation  L204
# Current point now = 68
# Current point  68  Rotation  R70
# Current point now = 38
# Current point  38  Rotation  R97
# Current point now = 35
# Current point  35  Rotation  L35
# Current point now = 0
# Current point  0  Rotation  L333
# Current point now = 67
# Current point  67  Rotation  R430
# Current point now = 97
# Current point  97  Rotation  L59
# Current point now = 38
# Current point  38  Rotation  R7
# Current point now = 45
# Current point  45  Rotation  L893
# Current point now = 52
# Current point  52  Rotation  L33
# Current point now = 19
# Current point  19  Rotation  L19
# Current point now = 0
# Current point  0  Rotation  L35
# Current point now = 65
# Current point  65  Rotation  R35
# Current point now = 0
# Current point  0  Rotation  R43
# Current point now = 43
# Current point  43  Rotation  L43
# Current point now = 0
# Current point  0  Rotation  R63
# Current point now = 63
# Current point  63  Rotation  L63
# Current point now = 0
# Current point  0  Rotation  R88
# Current point now = 88
# Current point  88  Rotation  L188
# Current point now = 0
# Current point  0  Rotation  L32
# Current point now = 68
# Current point  68  Rotation  R84
# Current point now = 52
# Current point  52  Rotation  L52
# Current point now = 0
# Current point  0  Rotation  R69
# Current point now = 69
# Current point  69  Rotation  R31
# Current point now = 0
# Current point  0  Rotation  L445
# Current point now = 55
# Current point  55  Rotation  L33
# Current point now = 22
# Current point  22  Rotation  L88
# Current point now = 34
# Current point  34  Rotation  R201
# Current point now = 35
# Current point  35  Rotation  L35
# Current point now = 0
# Current point  0  Rotation  L30
# Current point now = 70
# Current point  70  Rotation  R30
# Current point now = 0
# Current point  0  Rotation  R26
# Current point now = 26
# Current point  26  Rotation  L82
# Current point now = 44
# Current point  44  Rotation  L638
# Current point now = 6
# Current point  6  Rotation  R16
# Current point now = 22
# Current point  22  Rotation  L62
# Current point now = 60
# Current point  60  Rotation  L60
# Current point now = 0
# Current point  0  Rotation  R16
# Current point now = 16
# Current point  16  Rotation  L42
# Current point now = 74
# Current point  74  Rotation  R36
# Current point now = 10
# Current point  10  Rotation  L65
# Current point now = 45
# Current point  45  Rotation  L63
# Current point now = 82
# Current point  82  Rotation  R775
# Current point now = 57
# Current point  57  Rotation  L57
# Current point now = 0
# Current point  0  Rotation  L4
# Current point now = 96
# Current point  96  Rotation  R1
# Current point now = 97
# Current point  97  Rotation  L21
# Current point now = 76
# Current point  76  Rotation  R77
# Current point now = 53
# Current point  53  Rotation  R47
# Current point now = 0
# Current point  0  Rotation  L62
# Current point now = 38
# Current point  38  Rotation  R44
# Current point now = 82
# Current point  82  Rotation  R29
# Current point now = 11
# Current point  11  Rotation  L17
# Current point now = 94
# Current point  94  Rotation  R80
# Current point now = 74
# Current point  74  Rotation  R67
# Current point now = 41
# Current point  41  Rotation  L79
# Current point now = 62
# Current point  62  Rotation  L6
# Current point now = 56
# Current point  56  Rotation  R44
# Current point now = 0
# Current point  0  Rotation  R669
# Current point now = 69
# Current point  69  Rotation  R46
# Current point now = 15
# Current point  15  Rotation  L15
# Current point now = 0
# Current point  0  Rotation  L57
# Current point now = 43
# Current point  43  Rotation  L25
# Current point now = 18
# Current point  18  Rotation  R14
# Current point now = 32
# Current point  32  Rotation  L47
# Current point now = 85
# Current point  85  Rotation  R415
# Current point now = 0
# Current point  0  Rotation  L81
# Current point now = 19
# Current point  19  Rotation  L19
# Current point now = 0
# Current point  0  Rotation  L23
# Current point now = 77
# Current point  77  Rotation  R263
# Current point now = 40
# Current point  40  Rotation  L55
# Current point now = 85
# Current point  85  Rotation  L433
# Current point now = 52
# Current point  52  Rotation  L49
# Current point now = 3
# Current point  3  Rotation  R1
# Current point now = 4
# Current point  4  Rotation  L1
# Current point now = 3
# Current point  3  Rotation  L95
# Current point now = 8
# Current point  8  Rotation  R99
# Current point now = 7
# Current point  7  Rotation  L31
# Current point now = 76
# Current point  76  Rotation  L18
# Current point now = 58
# Current point  58  Rotation  R90
# Current point now = 48
# Current point  48  Rotation  R588
# Current point now = 36
# Current point  36  Rotation  R54
# Current point now = 90
# Current point  90  Rotation  L94
# Current point now = 96
# Current point  96  Rotation  L96
# Current point now = 0
# Current point  0  Rotation  L46
# Current point now = 54
# Current point  54  Rotation  R183
# Current point now = 37
# Current point  37  Rotation  L437
# Current point now = 0
# Current point  0  Rotation  R803
# Current point now = 3
# Current point  3  Rotation  L59
# Current point now = 44
# Current point  44  Rotation  R95
# Current point now = 39
# Current point  39  Rotation  L46
# Current point now = 93
# Current point  93  Rotation  L13
# Current point now = 80
# Current point  80  Rotation  R20
# Current point now = 0
# Current point  0  Rotation  L60
# Current point now = 40
# Current point  40  Rotation  R92
# Current point now = 32
# Current point  32  Rotation  L14
# Current point now = 18
# Current point  18  Rotation  L18
# Current point now = 0
# Current point  0  Rotation  L134
# Current point now = 66
# Current point  66  Rotation  L66
# Current point now = 0
# Current point  0  Rotation  R73
# Current point now = 73
# Current point  73  Rotation  R11
# Current point now = 84
# Current point  84  Rotation  L28
# Current point now = 56
# Current point  56  Rotation  L56
# Current point now = 0
# Current point  0  Rotation  R15
# Current point now = 15
# Current point  15  Rotation  R7
# Current point now = 22
# Current point  22  Rotation  R24
# Current point now = 46
# Current point  46  Rotation  L246
# Current point now = 0
# Current point  0  Rotation  L830
# Current point now = 70
# Current point  70  Rotation  R25
# Current point now = 95
# Current point  95  Rotation  R5
# Current point now = 0
# Current point  0  Rotation  L58
# Current point now = 42
# Current point  42  Rotation  L8
# Current point now = 34
# Current point  34  Rotation  R24
# Current point now = 58
# Current point  58  Rotation  L58
# Current point now = 0
# Current point  0  Rotation  R998
# Current point now = 98
# Current point  98  Rotation  R4
# Current point now = 2
# Current point  2  Rotation  R998
# Current point now = 0
# Current point  0  Rotation  L99
# Current point now = 1
# Current point  1  Rotation  R9
# Current point now = 10
# Current point  10  Rotation  R790
# Current point now = 0
# Current point  0  Rotation  L51
# Current point now = 49
# Current point  49  Rotation  R39
# Current point now = 88
# Current point  88  Rotation  L49
# Current point now = 39
# Current point  39  Rotation  L339
# Current point now = 0
# Current point  0  Rotation  L852
# Current point now = 48
# Current point  48  Rotation  L69
# Current point now = 79
# Current point  79  Rotation  L70
# Current point now = 9
# Current point  9  Rotation  R49
# Current point now = 58
# Current point  58  Rotation  L26
# Current point now = 32
# Current point  32  Rotation  R70
# Current point now = 2
# Current point  2  Rotation  R13
# Current point now = 15
# Current point  15  Rotation  R85
# Current point now = 0
# Current point  0  Rotation  L21
# Current point now = 79
# Current point  79  Rotation  L13
# Current point now = 66
# Current point  66  Rotation  L65
# Current point now = 1
# Current point  1  Rotation  L60
# Current point now = 41
# Current point  41  Rotation  L41
# Current point now = 0
# Current point  0  Rotation  R915
# Current point now = 15
# Current point  15  Rotation  L102
# Current point now = 13
# Current point  13  Rotation  R64
# Current point now = 77
# Current point  77  Rotation  R85
# Current point now = 62
# Current point  62  Rotation  R6
# Current point now = 68
# Current point  68  Rotation  R17
# Current point now = 85
# Current point  85  Rotation  L61
# Current point now = 24
# Current point  24  Rotation  R689
# Current point now = 13
# Current point  13  Rotation  L13
# Current point now = 0
# Current point  0  Rotation  R778
# Current point now = 78
# Current point  78  Rotation  L13
# Current point now = 65
# Current point  65  Rotation  L22
# Current point now = 43
# Current point  43  Rotation  R78
# Current point now = 21
# Current point  21  Rotation  R79
# Current point now = 0
# Current point  0  Rotation  L40
# Current point now = 60
# Current point  60  Rotation  L75
# Current point now = 85
# Current point  85  Rotation  L491
# Current point now = 94
# Current point  94  Rotation  R48
# Current point now = 42
# Current point  42  Rotation  R58
# Current point now = 0
# Current point  0  Rotation  L80
# Current point now = 20
# Current point  20  Rotation  L20
# Current point now = 0
# Current point  0  Rotation  R51
# Current point now = 51
# Current point  51  Rotation  L51
# Current point now = 0
# Current point  0  Rotation  R92
# Current point now = 92
# Current point  92  Rotation  R7
# Current point now = 99
# Current point  99  Rotation  R29
# Current point now = 28
# Current point  28  Rotation  R47
# Current point now = 75
# Current point  75  Rotation  R6
# Current point now = 81
# Current point  81  Rotation  L81
# Current point now = 0
# Current point  0  Rotation  R93
# Current point now = 93
# Current point  93  Rotation  L775
# Current point now = 18
# Current point  18  Rotation  L98
# Current point now = 20
# Current point  20  Rotation  R34
# Current point now = 54
# Current point  54  Rotation  L16
# Current point now = 38
# Current point  38  Rotation  L65
# Current point now = 73
# Current point  73  Rotation  L73
# Current point now = 0
# Current point  0  Rotation  R66
# Current point now = 66
# Current point  66  Rotation  R34
# Current point now = 0
# Current point  0  Rotation  R64
# Current point now = 64
# Current point  64  Rotation  L64
# Current point now = 0
# Current point  0  Rotation  R63
# Current point now = 63
# Current point  63  Rotation  R537
# Current point now = 0
# Current point  0  Rotation  L19
# Current point now = 81
# Current point  81  Rotation  R19
# Current point now = 0
# Current point  0  Rotation  R772
# Current point now = 72
# Current point  72  Rotation  L72
# Current point now = 0
# Current point  0  Rotation  R15
# Current point now = 15
# Current point  15  Rotation  R785
# Current point now = 0
# Current point  0  Rotation  L76
# Current point now = 24
# Current point  24  Rotation  R76
# Current point now = 0
# Current point  0  Rotation  R83
# Current point now = 83
# Current point  83  Rotation  R17
# Current point now = 0
# Current point  0  Rotation  R94
# Current point now = 94
# Current point  94  Rotation  R54
# Current point now = 48
# Current point  48  Rotation  R70
# Current point now = 18
# Current point  18  Rotation  R303
# Current point now = 21
# Current point  21  Rotation  R19
# Current point now = 40
# Current point  40  Rotation  R60
# Current point now = 0
# Current point  0  Rotation  L90
# Current point now = 10
# Current point  10  Rotation  L38
# Current point now = 72
# Current point  72  Rotation  L72
# Current point now = 0
# Current point  0  Rotation  R24
# Current point now = 24
# Current point  24  Rotation  R43
# Current point now = 67
# Current point  67  Rotation  L67
# Current point now = 0
# Current point  0  Rotation  R42
# Current point now = 42
# Current point  42  Rotation  R46
# Current point now = 88
# Current point  88  Rotation  R12
# Current point now = 0
# Current point  0  Rotation  R53
# Current point now = 53
# Current point  53  Rotation  R217
# Current point now = 70
# Current point  70  Rotation  R493
# Current point now = 63
# Current point  63  Rotation  R49
# Current point now = 12
# Current point  12  Rotation  R60
# Current point now = 72
# Current point  72  Rotation  R85
# Current point now = 57
# Current point  57  Rotation  L57
# Current point now = 0
# Current point  0  Rotation  R88
# Current point now = 88
# Current point  88  Rotation  L43
# Current point now = 45
# Current point  45  Rotation  L89
# Current point now = 56
# Current point  56  Rotation  R18
# Current point now = 74
# Current point  74  Rotation  L994
# Current point now = 80
# Current point  80  Rotation  L80
# Current point now = 0
# Current point  0  Rotation  R23
# Current point now = 23
# Current point  23  Rotation  R77
# Current point now = 0
# Current point  0  Rotation  L2
# Current point now = 98
# Current point  98  Rotation  R106
# Current point now = 4
# Current point  4  Rotation  R96
# Current point now = 0
# Current point  0  Rotation  L621
# Current point now = 79
# Current point  79  Rotation  R24
# Current point now = 3
# Current point  3  Rotation  L3
# Current point now = 0
# Current point  0  Rotation  R29
# Current point now = 29
# Current point  29  Rotation  L266
# Current point now = 63
# Current point  63  Rotation  L63
# Current point now = 0
# Current point  0  Rotation  L40
# Current point now = 60
# Current point  60  Rotation  R40
# Current point now = 0
# Current point  0  Rotation  L78
# Current point now = 22
# Current point  22  Rotation  L26
# Current point now = 96
# Current point  96  Rotation  R58
# Current point now = 54
# Current point  54  Rotation  R51
# Current point now = 5
# Current point  5  Rotation  R595
# Current point now = 0
# Current point  0  Rotation  L94
# Current point now = 6
# Current point  6  Rotation  L11
# Current point now = 95
# Current point  95  Rotation  R11
# Current point now = 6
# Current point  6  Rotation  R22
# Current point now = 28
# Current point  28  Rotation  R32
# Current point now = 60
# Current point  60  Rotation  R86
# Current point now = 46
# Current point  46  Rotation  L85
# Current point now = 61
# Current point  61  Rotation  R839
# Current point now = 0
# Current point  0  Rotation  L40
# Current point now = 60
# Current point  60  Rotation  L260
# Current point now = 0
# Current point  0  Rotation  L80
# Current point now = 20
# Current point  20  Rotation  R23
# Current point now = 43
# Current point  43  Rotation  L23
# Current point now = 20
# Current point  20  Rotation  L630
# Current point now = 90
# Current point  90  Rotation  L86
# Current point now = 4
# Current point  4  Rotation  L404
# Current point now = 0
# Current point  0  Rotation  L13
# Current point now = 87
# Current point  87  Rotation  R13
# Current point now = 0
# Current point  0  Rotation  R48
# Current point now = 48
# Current point  48  Rotation  L33
# Current point now = 15
# Current point  15  Rotation  L65
# Current point now = 50
# Current point  50  Rotation  R85
# Current point now = 35
# Current point  35  Rotation  R59
# Current point now = 94
# Current point  94  Rotation  R23
# Current point now = 17
# Current point  17  Rotation  L306
# Current point now = 11
# Current point  11  Rotation  R857
# Current point now = 68
# Current point  68  Rotation  L68
# Current point now = 0
# Current point  0  Rotation  R75
# Current point now = 75
# Current point  75  Rotation  R5
# Current point now = 80
# Current point  80  Rotation  R20
# Current point now = 0
# Current point  0  Rotation  L127
# Current point now = 73
# Current point  73  Rotation  R966
# Current point now = 39
# Current point  39  Rotation  R61
# Current point now = 0
# Current point  0  Rotation  R86
# Current point now = 86
# Current point  86  Rotation  R14
# Current point now = 0
# Current point  0  Rotation  L39
# Current point now = 61
# Current point  61  Rotation  R39
# Current point now = 0
# Current point  0  Rotation  R20
# Current point now = 20
# Current point  20  Rotation  L17
# Current point now = 3
# Current point  3  Rotation  L83
# Current point now = 20
# Current point  20  Rotation  L55
# Current point now = 65
# Current point  65  Rotation  L858
# Current point now = 7
# Current point  7  Rotation  L56
# Current point now = 51
# Current point  51  Rotation  L805
# Current point now = 46
# Current point  46  Rotation  R7
# Current point now = 53
# Current point  53  Rotation  R47
# Current point now = 0
# Current point  0  Rotation  R6
# Current point now = 6
# Current point  6  Rotation  R96
# Current point now = 2
# Current point  2  Rotation  R98
# Current point now = 0
# Current point  0  Rotation  L3
# Current point now = 97
# Current point  97  Rotation  R3
# Current point now = 0
# Current point  0  Rotation  R68
# Current point now = 68
# Current point  68  Rotation  R14
# Current point now = 82
# Current point  82  Rotation  L82
# Current point now = 0
# Current point  0  Rotation  R472
# Current point now = 72
# Current point  72  Rotation  L4
# Current point now = 68
# Current point  68  Rotation  L49
# Current point now = 19
# Current point  19  Rotation  R81
# Current point now = 0
# Current point  0  Rotation  L93
# Current point now = 7
# Current point  7  Rotation  L907
# Current point now = 0
# Current point  0  Rotation  L47
# Current point now = 53
# Current point  53  Rotation  R65
# Current point now = 18
# Current point  18  Rotation  L78
# Current point now = 40
# Current point  40  Rotation  R130
# Current point now = 70
# Current point  70  Rotation  L35
# Current point now = 35
# Current point  35  Rotation  R65
# Current point now = 0
# Current point  0  Rotation  L55
# Current point now = 45
# Current point  45  Rotation  L72
# Current point now = 73
# Current point  73  Rotation  R83
# Current point now = 56
# Current point  56  Rotation  R52
# Current point now = 8
# Current point  8  Rotation  L8
# Current point now = 0
# Current point  0  Rotation  L10
# Current point now = 90
# Current point  90  Rotation  L490
# Current point now = 0
# Current point  0  Rotation  R14
# Current point now = 14
# Current point  14  Rotation  R34
# Current point now = 48
# Current point  48  Rotation  R52
# Current point now = 0
# Current point  0  Rotation  R415
# Current point now = 15
# Current point  15  Rotation  R75
# Current point now = 90
# Current point  90  Rotation  R68
# Current point now = 58
# Current point  58  Rotation  L360
# Current point now = 98
# Current point  98  Rotation  L74
# Current point now = 24
# Current point  24  Rotation  L24
# Current point now = 0
# Current point  0  Rotation  L3
# Current point now = 97
# Current point  97  Rotation  L20
# Current point now = 77
# Current point  77  Rotation  L63
# Current point now = 14
# Current point  14  Rotation  L14
# Current point now = 0
# Current point  0  Rotation  L3
# Current point now = 97
# Current point  97  Rotation  R9
# Current point now = 6
# Current point  6  Rotation  L21
# Current point now = 85
# Current point  85  Rotation  R15
# Current point now = 0
# Current point  0  Rotation  L971
# Current point now = 29
# Current point  29  Rotation  R25
# Current point now = 54
# Current point  54  Rotation  L43
# Current point now = 11
# Current point  11  Rotation  L97
# Current point now = 14
# Current point  14  Rotation  R221
# Current point now = 35
# Current point  35  Rotation  L35
# Current point now = 0
# Current point  0  Rotation  L10
# Current point now = 90
# Current point  90  Rotation  L390
# Current point now = 0
# Current point  0  Rotation  L31
# Current point now = 69
# Current point  69  Rotation  R384
# Current point now = 53
# Current point  53  Rotation  L941
# Current point now = 12
# Current point  12  Rotation  L12
# Current point now = 0
# Current point  0  Rotation  L55
# Current point now = 45
# Current point  45  Rotation  L23
# Current point now = 22
# Current point  22  Rotation  R78
# Current point now = 0
# Current point  0  Rotation  R51
# Current point now = 51
# Current point  51  Rotation  R695
# Current point now = 46
# Current point  46  Rotation  R54
# Current point now = 0
# Current point  0  Rotation  R305
# Current point now = 5
# Current point  5  Rotation  L315
# Current point now = 90
# Current point  90  Rotation  R10
# Current point now = 0
# Current point  0  Rotation  R58
# Current point now = 58
# Current point  58  Rotation  L16
# Current point now = 42
# Current point  42  Rotation  L78
# Current point now = 64
# Current point  64  Rotation  L59
# Current point now = 5
# Current point  5  Rotation  R2
# Current point now = 7
# Current point  7  Rotation  L76
# Current point now = 31
# Current point  31  Rotation  R786
# Current point now = 17
# Current point  17  Rotation  R10
# Current point now = 27
# Current point  27  Rotation  R80
# Current point now = 7
# Current point  7  Rotation  L29
# Current point now = 78
# Current point  78  Rotation  L78
# Current point now = 0
# Current point  0  Rotation  L96
# Current point now = 4
# Current point  4  Rotation  L804
# Current point now = 0
# Current point  0  Rotation  R889
# Current point now = 89
# Current point  89  Rotation  R17
# Current point now = 6
# Current point  6  Rotation  L87
# Current point now = 19
# Current point  19  Rotation  L19
# Current point now = 0
# Current point  0  Rotation  R42
# Current point now = 42
# Current point  42  Rotation  L20
# Current point now = 22
# Current point  22  Rotation  L15
# Current point now = 7
# Current point  7  Rotation  L251
# Current point now = 56
# Current point  56  Rotation  R82
# Current point now = 38
# Current point  38  Rotation  R829
# Current point now = 67
# Current point  67  Rotation  L87
# Current point now = 80
# Current point  80  Rotation  R69
# Current point now = 49
# Current point  49  Rotation  L35
# Current point now = 14
# Current point  14  Rotation  R10
# Current point now = 24
# Current point  24  Rotation  R74
# Current point now = 98
# Current point  98  Rotation  L457
# Current point now = 41
# Current point  41  Rotation  L51
# Current point now = 90
# Current point  90  Rotation  L7
# Current point now = 83
# Current point  83  Rotation  R31
# Current point now = 14
# Current point  14  Rotation  R82
# Current point now = 96
# Current point  96  Rotation  R55
# Current point now = 51
# Current point  51  Rotation  R19
# Current point now = 70
# Current point  70  Rotation  R30
# Current point now = 0
# Current point  0  Rotation  R94
# Current point now = 94
# Current point  94  Rotation  L94
# Current point now = 0
# Current point  0  Rotation  R99
# Current point now = 99
# Current point  99  Rotation  R259
# Current point now = 58
# Current point  58  Rotation  R42
# Current point now = 0
# Current point  0  Rotation  R18
# Current point now = 18
# Current point  18  Rotation  L718
# Current point now = 0
# Current point  0  Rotation  R92
# Current point now = 92
# Current point  92  Rotation  L56
# Current point now = 36
# Current point  36  Rotation  L36
# Current point now = 0
# Current point  0  Rotation  L403
# Current point now = 97
# Current point  97  Rotation  L25
# Current point now = 72
# Current point  72  Rotation  R28
# Current point now = 0
# Current point  0  Rotation  L331
# Current point now = 69
# Current point  69  Rotation  R31
# Current point now = 0
# Current point  0  Rotation  R70
# Current point now = 70
# Current point  70  Rotation  R13
# Current point now = 83
# Current point  83  Rotation  L77
# Current point now = 6
# Current point  6  Rotation  R94
# Current point now = 0
# Current point  0  Rotation  L33
# Current point now = 67
# Current point  67  Rotation  L776
# Current point now = 91
# Current point  91  Rotation  R56
# Current point now = 47
# Current point  47  Rotation  L48
# Current point now = 99
# Current point  99  Rotation  R64
# Current point now = 63
# Current point  63  Rotation  R21
# Current point now = 84
# Current point  84  Rotation  R97
# Current point now = 81
# Current point  81  Rotation  R19
# Current point now = 0
# Current point  0  Rotation  L694
# Current point now = 6
# Current point  6  Rotation  L953
# Current point now = 53
# Current point  53  Rotation  R63
# Current point now = 16
# Current point  16  Rotation  R884
# Current point now = 0
# Current point  0  Rotation  R356
# Current point now = 56
# Current point  56  Rotation  L56
# Current point now = 0
# Current point  0  Rotation  R532
# Current point now = 32
# Current point  32  Rotation  L88
# Current point now = 44
# Current point  44  Rotation  R576
# Current point now = 20
# Current point  20  Rotation  L44
# Current point now = 76
# Current point  76  Rotation  R254
# Current point now = 30
# Current point  30  Rotation  L530
# Current point now = 0
# Current point  0  Rotation  R6
# Current point now = 6
# Current point  6  Rotation  R65
# Current point now = 71
# Current point  71  Rotation  L671
# Current point now = 0
# Current point  0  Rotation  R10
# Current point now = 10
# Current point  10  Rotation  R90
# Current point now = 0
# Current point  0  Rotation  L74
# Current point now = 26
# Current point  26  Rotation  L536
# Current point now = 90
# Current point  90  Rotation  R10
# Current point now = 0
# Current point  0  Rotation  R44
# Current point now = 44
# Current point  44  Rotation  R92
# Current point now = 36
# Current point  36  Rotation  L5
# Current point now = 31
# Current point  31  Rotation  L720
# Current point now = 11
# Current point  11  Rotation  L476
# Current point now = 35
# Current point  35  Rotation  R176
# Current point now = 11
# Current point  11  Rotation  L628
# Current point now = 83
# Current point  83  Rotation  L83
# Current point now = 0
# Current point  0  Rotation  L89
# Current point now = 11
# Current point  11  Rotation  L41
# Current point now = 70
# Current point  70  Rotation  R15
# Current point now = 85
# Current point  85  Rotation  R15
# Current point now = 0
# Current point  0  Rotation  R58
# Current point now = 58
# Current point  58  Rotation  L158
# Current point now = 0
# Current point  0  Rotation  L53
# Current point now = 47
# Current point  47  Rotation  R53
# Current point now = 0
# Current point  0  Rotation  L35
# Current point now = 65
# Current point  65  Rotation  R45
# Current point now = 10
# Current point  10  Rotation  R390
# Current point now = 0
# Current point  0  Rotation  R15
# Current point now = 15
# Current point  15  Rotation  L89
# Current point now = 26
# Current point  26  Rotation  R22
# Current point now = 48
# Current point  48  Rotation  L48
# Current point now = 0
# Current point  0  Rotation  R51
# Current point now = 51
# Current point  51  Rotation  L77
# Current point now = 74
# Current point  74  Rotation  R3
# Current point now = 77
# Current point  77  Rotation  R65
# Current point now = 42
# Current point  42  Rotation  R58
# Current point now = 0
# Current point  0  Rotation  R79
# Current point now = 79
# Current point  79  Rotation  R137
# Current point now = 16
# Current point  16  Rotation  R40
# Current point now = 56
# Current point  56  Rotation  R84
# Current point now = 40
# Current point  40  Rotation  R6
# Current point now = 46
# Current point  46  Rotation  L52
# Current point now = 94
# Current point  94  Rotation  L994
# Current point now = 0
# Current point  0  Rotation  R28
# Current point now = 28
# Current point  28  Rotation  L4
# Current point now = 24
# Current point  24  Rotation  L35
# Current point now = 89
# Current point  89  Rotation  R11
# Current point now = 0
# Current point  0  Rotation  R19
# Current point now = 19
# Current point  19  Rotation  L74
# Current point now = 45
# Current point  45  Rotation  R55
# Current point now = 0
# Current point  0  Rotation  R77
# Current point now = 77
# Current point  77  Rotation  R53
# Current point now = 30
# Current point  30  Rotation  R70
# Current point now = 0
# Current point  0  Rotation  L89
# Current point now = 11
# Current point  11  Rotation  L9
# Current point now = 2
# Current point  2  Rotation  R52
# Current point now = 54
# Current point  54  Rotation  R96
# Current point now = 50
# Current point  50  Rotation  R19
# Current point now = 69
# Current point  69  Rotation  L56
# Current point now = 13
# Current point  13  Rotation  R26
# Current point now = 39
# Current point  39  Rotation  L39
# Current point now = 0
# Current point  0  Rotation  L93
# Current point now = 7
# Current point  7  Rotation  L34
# Current point now = 73
# Current point  73  Rotation  L55
# Current point now = 18
# Current point  18  Rotation  L18
# Current point now = 0
# Current point  0  Rotation  R14
# Current point now = 14
# Current point  14  Rotation  R972
# Current point now = 86
# Current point  86  Rotation  L37
# Current point now = 49
# Current point  49  Rotation  L2
# Current point now = 47
# Current point  47  Rotation  L854
# Current point now = 93
# Current point  93  Rotation  R88
# Current point now = 81
# Current point  81  Rotation  L11
# Current point now = 70
# Current point  70  Rotation  R93
# Current point now = 63
# Current point  63  Rotation  L618
# Current point now = 45
# Current point  45  Rotation  L134
# Current point now = 11
# Current point  11  Rotation  L11
# Current point now = 0
# Current point  0  Rotation  L439
# Current point now = 61
# Current point  61  Rotation  L61
# Current point now = 0
# Current point  0  Rotation  R932
# Current point now = 32
# Current point  32  Rotation  L90
# Current point now = 42
# Current point  42  Rotation  L57
# Current point now = 85
# Current point  85  Rotation  R96
# Current point now = 81
# Current point  81  Rotation  L73
# Current point now = 8
# Current point  8  Rotation  R655
# Current point now = 63
# Current point  63  Rotation  R623
# Current point now = 86
# Current point  86  Rotation  R799
# Current point now = 85
# Current point  85  Rotation  L30
# Current point now = 55
# Current point  55  Rotation  L55
# ...
# Current point  2  Rotation  R86
# Current point now = 88
# Current point  88  Rotation  L88
# Current point now = 0
# Current point  0  Rotation  R55
# Current point now = 55
# Current point  55  Rotation  L310
# Current point now = 45
# Current point  45  Rotation  R55
# Current point now = 0
# Current point  0  Rotation  L19
# Current point now = 81
# Current point  81  Rotation  L8
# Current point now = 73
# Current point  73  Rotation  L92
# Current point now = 81
# Current point  81  Rotation  L80
# Current point now = 1
# Current point  1  Rotation  L39
# Current point now = 62
# Current point  62  Rotation  R55
# Current point now = 17
# Current point  17  Rotation  L89
# Current point now = 28
# Current point  28  Rotation  L65
# Current point now = 63
# Current point  63  Rotation  R37
# Current point now = 0
# Current point  0  Rotation  L70
# Current point now = 30
# Current point  30  Rotation  R32
# Current point now = 62
# Current point  62  Rotation  R9
# Current point now = 71
# Current point  71  Rotation  R29
# Current point now = 0
# Current point  0  Rotation  L325
# Current point now = 75
# Current point  75  Rotation  L75
# Current point now = 0
# Current point  0  Rotation  L17
# Current point now = 83
# Current point  83  Rotation  L483
# Current point now = 0
# Current point  0  Rotation  L32
# Current point now = 68
# Current point  68  Rotation  L68
# Current point now = 0
# Current point  0  Rotation  R1
# Current point now = 1
# Current point  1  Rotation  L81
# Current point now = 20
# Current point  20  Rotation  L20
# Current point now = 0
# Current point  0  Rotation  L99
# Current point now = 1
# Current point  1  Rotation  R15
# Current point now = 16
# Current point  16  Rotation  L16
# Current point now = 0
# Current point  0  Rotation  R58
# Current point now = 58
# Current point  58  Rotation  R880
# Current point now = 38
# Current point  38  Rotation  R89
# Current point now = 27
# Current point  27  Rotation  R173
# Current point now = 0
# Current point  0  Rotation  L660
# Current point now = 40
# Current point  40  Rotation  R56
# Current point now = 96
# Current point  96  Rotation  R4
# Current point now = 0
# Current point  0  Rotation  R47
# Current point now = 47
# Current point  47  Rotation  R79
# Current point now = 26
# Current point  26  Rotation  L757
# Current point now = 69
# Current point  69  Rotation  R22
# Current point now = 91
# Current point  91  Rotation  L596
# Current point now = 95
# Current point  95  Rotation  R50
# Current point now = 45
# Current point  45  Rotation  L34
# Current point now = 11
# Current point  11  Rotation  L65
# Current point now = 46
# Current point  46  Rotation  R654
# Current point now = 0
# Current point  0  Rotation  R25
# Current point now = 25
# Current point  25  Rotation  R8
# Current point now = 33
# Current point  33  Rotation  L60
# Current point now = 73
# Current point  73  Rotation  L56
# Current point now = 17
# Current point  17  Rotation  L62
# Current point now = 55
# Current point  55  Rotation  R95
# Current point now = 50
# Current point  50  Rotation  L92
# Current point now = 58
# Current point  58  Rotation  R42
# Current point now = 0
# Current point  0  Rotation  L97
# Current point now = 3
# Current point  3  Rotation  L93
# Current point now = 10
# Current point  10  Rotation  L957
# Current point now = 53
# Current point  53  Rotation  L626
# Current point now = 27
# Current point  27  Rotation  L27
# Current point now = 0
# Current point  0  Rotation  R48
# Current point now = 48
# Current point  48  Rotation  R21
# Current point now = 69
# Current point  69  Rotation  L69
# Current point now = 0
# Current point  0  Rotation  R777
# Current point now = 77
# Current point  77  Rotation  R23
# Current point now = 0
# Current point  0  Rotation  L43
# Current point now = 57
# Current point  57  Rotation  R443
# Current point now = 0
# Current point  0  Rotation  R621
# Current point now = 21
# Current point  21  Rotation  L121
# Current point now = 0
# Current point  0  Rotation  L70
# Current point now = 30
# Current point  30  Rotation  R75
# Current point now = 5
# Current point  5  Rotation  L69
# Current point now = 36
# Current point  36  Rotation  L636
# Current point now = 0
# Current point  0  Rotation  R19
# Current point now = 19
# Current point  19  Rotation  R96
# Current point now = 15
# Current point  15  Rotation  L6
# Current point now = 9
# Current point  9  Rotation  L78
# Current point now = 31
# Current point  31  Rotation  R978
# Current point now = 9
# Current point  9  Rotation  L851
# Current point now = 58
# Current point  58  Rotation  R42
# Current point now = 0
# Current point  0  Rotation  L17
# Current point now = 83
# Current point  83  Rotation  L36
# Current point now = 47
# Current point  47  Rotation  R36
# Current point now = 83
# Current point  83  Rotation  L790
# Current point now = 93
# Current point  93  Rotation  R7
# Current point now = 0
# Current point  0  Rotation  R10
# Current point now = 10
# Current point  10  Rotation  L27
# Current point now = 83
# Current point  83  Rotation  R39
# Current point now = 22
# Current point  22  Rotation  L28
# Current point now = 94
# Current point  94  Rotation  L58
# Current point now = 36
# Current point  36  Rotation  R70
# Current point now = 6
# Current point  6  Rotation  L320
# Current point now = 86
# Current point  86  Rotation  R14
# Current point now = 0
# Current point  0  Rotation  L27
# Current point now = 73
# Current point  73  Rotation  R426
# Current point now = 99
# Current point  99  Rotation  L11
# Current point now = 88
# Current point  88  Rotation  L43
# Current point now = 45
# Current point  45  Rotation  L16
# Current point now = 29
# Current point  29  Rotation  L64
# Current point now = 65
# Current point  65  Rotation  L65
# Current point now = 0
# Current point  0  Rotation  L747
# Current point now = 53
# Current point  53  Rotation  R22
# Current point now = 75
# Current point  75  Rotation  L58
# Current point now = 17
# Current point  17  Rotation  L64
# Current point now = 53
# Current point  53  Rotation  L53
# Current point now = 0
# Current point  0  Rotation  R77
# Current point now = 77
# Current point  77  Rotation  L824
# Current point now = 53
# Current point  53  Rotation  R47
# Current point now = 0
# Current point  0  Rotation  L827
# Current point now = 73
# Current point  73  Rotation  R527
# Current point now = 0
# Current point  0  Rotation  R13
# Current point now = 13
# Current point  13  Rotation  L99
# Current point now = 14
# Current point  14  Rotation  L14
# Current point now = 0
# Current point  0  Rotation  R33
# Current point now = 33
# Current point  33  Rotation  L45
# Current point now = 88
# Current point  88  Rotation  R92
# Current point now = 80
# Current point  80  Rotation  R20
# Current point now = 0
# Current point  0  Rotation  L559
# Current point now = 41
# Current point  41  Rotation  L53
# Current point now = 88
# Current point  88  Rotation  R12
# Current point now = 0
# Current point  0  Rotation  L82
# Current point now = 18
# Current point  18  Rotation  L18
# Current point now = 0
# Current point  0  Rotation  L55
# Current point now = 45
# Current point  45  Rotation  R4
# Current point now = 49
# Current point  49  Rotation  R851
# Current point now = 0
# Current point  0  Rotation  R73
# Current point now = 73
# Current point  73  Rotation  R69
# Current point now = 42
# Current point  42  Rotation  L42
# Current point now = 0
# Current point  0  Rotation  R63
# Current point now = 63
# Current point  63  Rotation  R8
# Current point now = 71
# Current point  71  Rotation  R29
# Current point now = 0
# Current point  0  Rotation  R23
# Current point now = 23
# Current point  23  Rotation  L1
# Current point now = 22
# Current point  22  Rotation  R31
# Current point now = 53
# Current point  53  Rotation  R57
# Current point now = 10
# Current point  10  Rotation  L97
# Current point now = 13
# Current point  13  Rotation  L13
# Current point now = 0
# Current point  0  Rotation  R743
# Current point now = 43
# Current point  43  Rotation  R57
# Current point now = 0
# Current point  0  Rotation  L277
# Current point now = 23
# Current point  23  Rotation  R61
# Current point now = 84
# Current point  84  Rotation  L69
# Current point now = 15
# Current point  15  Rotation  R923
# Current point now = 38
# Current point  38  Rotation  R88
# Current point now = 26
# Current point  26  Rotation  R9
# Current point now = 35
# Current point  35  Rotation  R65
# Current point now = 0
# Current point  0  Rotation  R18
# Current point now = 18
# Current point  18  Rotation  L18
# Current point now = 0
# Current point  0  Rotation  R16
# Current point now = 16
# Current point  16  Rotation  L194
# Current point now = 22
# Current point  22  Rotation  L63
# Current point now = 59
# Current point  59  Rotation  L73
# Current point now = 86
# Current point  86  Rotation  L74
# Current point now = 12
# Current point  12  Rotation  L480
# Current point now = 32
# Current point  32  Rotation  L32
# Current point now = 0
# Current point  0  Rotation  R18
# Current point now = 18
# Current point  18  Rotation  L53
# Current point now = 65
# Current point  65  Rotation  R39
# Current point now = 4
# Current point  4  Rotation  L404
# Current point now = 0
# Current point  0  Rotation  R381
# Current point now = 81
# Current point  81  Rotation  R6
# Current point now = 87
# Current point  87  Rotation  R13
# Current point now = 0
# Current point  0  Rotation  L71
# Current point now = 29
# Current point  29  Rotation  R76
# Current point now = 5
# Current point  5  Rotation  R42
# Current point now = 47
# Current point  47  Rotation  R16
# Current point now = 63
# Current point  63  Rotation  L63
# Current point now = 0
# Current point  0  Rotation  R210
# Current point now = 10
# Current point  10  Rotation  L10
# Current point now = 0
# Current point  0  Rotation  L75
# Current point now = 25
# Current point  25  Rotation  R49
# Current point now = 74
# Current point  74  Rotation  L74
# Current point now = 0
# Current point  0  Rotation  R54
# Current point now = 54
# Current point  54  Rotation  R22
# Current point now = 76
# Current point  76  Rotation  L50
# Current point now = 26
# Current point  26  Rotation  L21
# Current point now = 5
# Current point  5  Rotation  R143
# Current point now = 48
# Current point  48  Rotation  R108
# Current point now = 56
# Current point  56  Rotation  R21
# Current point now = 77
# Current point  77  Rotation  L77
# Current point now = 0
# Current point  0  Rotation  L81
# Current point now = 19
# Current point  19  Rotation  R281
# Current point now = 0
# Current point  0  Rotation  R23
# Current point now = 23
# Current point  23  Rotation  R87
# Current point now = 10
# Current point  10  Rotation  L75
# Current point now = 35
# Current point  35  Rotation  L52
# Current point now = 83
# Current point  83  Rotation  R51
# Current point now = 34
# Current point  34  Rotation  R22
# Current point now = 56
# Current point  56  Rotation  L51
# Current point now = 5
# Current point  5  Rotation  L82
# Current point now = 23
# Current point  23  Rotation  L23
# Current point now = 0
# Current point  0  Rotation  R10
# Current point now = 10
# Current point  10  Rotation  L29
# Current point now = 81
# Current point  81  Rotation  R22
# Current point now = 3
# Current point  3  Rotation  R97
# Current point now = 0
# Current point  0  Rotation  L1
# Current point now = 99
# Current point  99  Rotation  L97
# Current point now = 2
# Current point  2  Rotation  R44
# Current point now = 46
# Current point  46  Rotation  L39
# Current point now = 7
# Current point  7  Rotation  R1
# Current point now = 8
# Current point  8  Rotation  L46
# Current point now = 62
# Current point  62  Rotation  L62
# Current point now = 0
# Current point  0  Rotation  L90
# Current point now = 10
# Current point  10  Rotation  R66
# Current point now = 76
# Current point  76  Rotation  R24
# Current point now = 0
# Current point  0  Rotation  R50
# Current point now = 50
# Current point  50  Rotation  R96
# Current point now = 46
# Current point  46  Rotation  R68
# Current point now = 14
# Current point  14  Rotation  L9
# Current point now = 5
# Current point  5  Rotation  R95
# Current point now = 0
# Current point  0  Rotation  L62
# Current point now = 38
# Current point  38  Rotation  L25
# Current point now = 13
# Current point  13  Rotation  L49
# Current point now = 64
# Current point  64  Rotation  L56
# Current point now = 8
# Current point  8  Rotation  L82
# Current point now = 26
# Current point  26  Rotation  R30
# Current point now = 56
# Current point  56  Rotation  L65
# Current point now = 91
# Current point  91  Rotation  L81
# Current point now = 10
# Current point  10  Rotation  L10
# Current point now = 0
# Current point  0  Rotation  L73
# Current point now = 27
# Current point  27  Rotation  L62
# Current point now = 65
# Current point  65  Rotation  L31
# Current point now = 34
# Current point  34  Rotation  R66
# Current point now = 0
# Current point  0  Rotation  R97
# Current point now = 97
# Current point  97  Rotation  R73
# Current point now = 70
# Current point  70  Rotation  L61
# Current point now = 9
# Current point  9  Rotation  R18
# Current point now = 27
# Current point  27  Rotation  L94
# Current point now = 33
# Current point  33  Rotation  R81
# Current point now = 14
# Current point  14  Rotation  R86
# Current point now = 0
# Current point  0  Rotation  L74
# Current point now = 26
# Current point  26  Rotation  R31
# Current point now = 57
# Current point  57  Rotation  L57
# Current point now = 0
# Current point  0  Rotation  L62
# Current point now = 38
# Current point  38  Rotation  L38
# Current point now = 0
# Current point  0  Rotation  L74
# Current point now = 26
# Current point  26  Rotation  R74
# Current point now = 0
# Current point  0  Rotation  R33
# Current point now = 33
# Current point  33  Rotation  R5
# Current point now = 38
# Current point  38  Rotation  L1
# Current point now = 37
# Current point  37  Rotation  R50
# Current point now = 87
# Current point  87  Rotation  R47
# Current point now = 34
# Current point  34  Rotation  R41
# Current point now = 75
# Current point  75  Rotation  R35
# Current point now = 10
# Current point  10  Rotation  L3
# Current point now = 7
# Current point  7  Rotation  R38
# Current point now = 45
# Current point  45  Rotation  R41
# Current point now = 86
# Current point  86  Rotation  L39
# Current point now = 47
# Current point  47  Rotation  L27
# Current point now = 20
# Current point  20  Rotation  R48
# Current point now = 68
# Current point  68  Rotation  L40
# Current point now = 28
# Current point  28  Rotation  R4
# Current point now = 32
# Current point  32  Rotation  R31
# Current point now = 63
# Current point  63  Rotation  R48
# Current point now = 11
# Current point  11  Rotation  R12
# Current point now = 23
# Current point  23  Rotation  L45
# Current point now = 78
# Current point  78  Rotation  L27
# Current point now = 51
# Current point  51  Rotation  L26
# Current point now = 25
# Current point  25  Rotation  R38
# Current point now = 63
# Current point  63  Rotation  L43
# Current point now = 20
# Current point  20  Rotation  R23
# Current point now = 43
# Current point  43  Rotation  R12
# Current point now = 55
# Current point  55  Rotation  L21
# Current point now = 34
# Current point  34  Rotation  R34
# Current point now = 68
# Current point  68  Rotation  L18
# Current point now = 50
# Current point  50  Rotation  R10
# Current point now = 60
# Current point  60  Rotation  R20
# Current point now = 80
# Current point  80  Rotation  L7
# Current point now = 73
# Current point  73  Rotation  L16
# Current point now = 57
# Current point  57  Rotation  L43
# Current point now = 14
# Current point  14  Rotation  L19
# Current point now = 95
# Current point  95  Rotation  L1
# Current point now = 94
# Current point  94  Rotation  L42
# Current point now = 52
# Current point  52  Rotation  L50
# Current point now = 2
# Current point  2  Rotation  L3
# Current point now = 99
# Current point  99  Rotation  L33
# Current point now = 66
# Current point  66  Rotation  L39
# Current point now = 27
# Current point  27  Rotation  L2
# Current point now = 25
# Current point  25  Rotation  L32
# Current point now = 93
# Current point  93  Rotation  L36
# Current point now = 57
# Current point  57  Rotation  R33
# Current point now = 90
# Current point  90  Rotation  L5
# Current point now = 85
# Current point  85  Rotation  L12
# Current point now = 73
# Current point  73  Rotation  R2
# Current point now = 75
# Current point  75  Rotation  L14
# Current point now = 61
# Current point  61  Rotation  R10
# Current point now = 71
# Current point  71  Rotation  L13
# Current point now = 58
# Current point  58  Rotation  L35
# Current point now = 23
# Current point  23  Rotation  R47
# Current point now = 70
# 1139

# %% [markdown]
# --- Part Two ---
#
# You're sure that's the right password, but the door won't open. You knock, but nobody answers. You build a snowman while you think.
#
# As you're rolling the snowballs for your snowman, you find another security document that must have fallen into the snow:
#
# "Due to newer security protocols, please use password method 0x434C49434B until further notice."
#
# You remember from the training seminar that "method 0x434C49434B" means you're actually supposed to count the number of times any click causes the dial to point at 0, regardless of whether it happens during a rotation or at the end of one.

# %%
-5//100
5//100
# Out:
# 0

# %%
def make_rotation_0x434C49434B(rotation, current_point):
    print("Current point ", str(current_point), " Rotation ", rotation)
    right = True if rotation[0]=="R" else False
    distance = int(rotation[1:])

    # hacky hack
    if current_point==0 and not right:
        current_point=100
    
    if right:
        x = current_point+distance
    else:
        x = current_point-distance
    

    current_point, increment = x%100, abs(x//100) 
    
    #hacky hack
    if current_point==0:
        increment+=1
    
    print("x = ", str(x), " Current point now = "+str(current_point), " increment = "+str(increment),"\n")
    return current_point, increment

def get_password_0x434C49434B(data):
    current_point = 50
    count=0
    for d in data:
        current_point, inc = make_rotation_0x434C49434B(d, current_point)
        count=count+inc
    return count

test_data = ["L68", "L30", "R48", "L5", "R60", "L55", "L1", "L99", "R14", "L82"]
print(get_password_0x434C49434B(test_data))
# Out:
# Current point  50  Rotation  L68
# x =  -18  Current point now = 82  increment = 1
#
# Current point  82  Rotation  L30
# x =  52  Current point now = 52  increment = 0
#
# Current point  52  Rotation  R48
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L5
# x =  95  Current point now = 95  increment = 0
#
# Current point  95  Rotation  R60
# x =  155  Current point now = 55  increment = 1
#
# Current point  55  Rotation  L55
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L1
# x =  99  Current point now = 99  increment = 0
#
# Current point  99  Rotation  L99
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R14
# x =  14  Current point now = 14  increment = 0
#
# Current point  14  Rotation  L82
# x =  -68  Current point now = 32  increment = 1
#
# 7

# %% [markdown]
# Following the same rotations as in the above example, the dial points at zero a few extra times during its rotations:
#
# The dial starts by pointing at 50.
# The dial is rotated L68 to point at 82; during this rotation, it points at 0 once.
# The dial is rotated L30 to point at 52.
# The dial is rotated R48 to point at 0.
# The dial is rotated L5 to point at 95.
# The dial is rotated R60 to point at 55; during this rotation, it points at 0 once.
# The dial is rotated L55 to point at 0.
# The dial is rotated L1 to point at 99.
# The dial is rotated L99 to point at 0.
# The dial is rotated R14 to point at 14.
# The dial is rotated L82 to point at 32; during this rotation, it points at 0 once.
# In this example, the dial points at 0 three times at the end of a rotation, plus three more times during a rotation. So, in this example, the new password would be 6.
#
# Be careful: if the dial were pointing at 50, a single rotation like R1000 would cause the dial to point at 0 ten times before returning back to 50!
#
# Using password method 0x434C49434B, what is the password to open the door?

# %%
get_password_0x434C49434B(combinations)
# Out:
# Current point  50  Rotation  R1
# x =  51  Current point now = 51  increment = 0
#
# Current point  51  Rotation  R25
# x =  76  Current point now = 76  increment = 0
#
# Current point  76  Rotation  R50
# x =  126  Current point now = 26  increment = 1
#
# Current point  26  Rotation  R10
# x =  36  Current point now = 36  increment = 0
#
# Current point  36  Rotation  L20
# x =  16  Current point now = 16  increment = 0
#
# Current point  16  Rotation  L14
# x =  2  Current point now = 2  increment = 0
#
# Current point  2  Rotation  L26
# x =  -24  Current point now = 76  increment = 1
#
# Current point  76  Rotation  L5
# x =  71  Current point now = 71  increment = 0
#
# Current point  71  Rotation  R19
# x =  90  Current point now = 90  increment = 0
#
# Current point  90  Rotation  R35
# x =  125  Current point now = 25  increment = 1
#
# Current point  25  Rotation  R36
# x =  61  Current point now = 61  increment = 0
#
# Current point  61  Rotation  R1
# x =  62  Current point now = 62  increment = 0
#
# Current point  62  Rotation  L50
# x =  12  Current point now = 12  increment = 0
#
# Current point  12  Rotation  L20
# x =  -8  Current point now = 92  increment = 1
#
# Current point  92  Rotation  L34
# x =  58  Current point now = 58  increment = 0
#
# Current point  58  Rotation  L2
# x =  56  Current point now = 56  increment = 0
#
# Current point  56  Rotation  L31
# x =  25  Current point now = 25  increment = 0
#
# Current point  25  Rotation  L22
# x =  3  Current point now = 3  increment = 0
#
# Current point  3  Rotation  L8
# x =  -5  Current point now = 95  increment = 1
#
# Current point  95  Rotation  L43
# x =  52  Current point now = 52  increment = 0
#
# Current point  52  Rotation  R25
# x =  77  Current point now = 77  increment = 0
#
# Current point  77  Rotation  L20
# x =  57  Current point now = 57  increment = 0
#
# Current point  57  Rotation  L18
# x =  39  Current point now = 39  increment = 0
#
# Current point  39  Rotation  L14
# x =  25  Current point now = 25  increment = 0
#
# Current point  25  Rotation  R24
# x =  49  Current point now = 49  increment = 0
#
# Current point  49  Rotation  L30
# x =  19  Current point now = 19  increment = 0
#
# Current point  19  Rotation  L48
# x =  -29  Current point now = 71  increment = 1
#
# Current point  71  Rotation  L2
# x =  69  Current point now = 69  increment = 0
#
# Current point  69  Rotation  L23
# x =  46  Current point now = 46  increment = 0
#
# Current point  46  Rotation  L7
# x =  39  Current point now = 39  increment = 0
#
# Current point  39  Rotation  R46
# x =  85  Current point now = 85  increment = 0
#
# Current point  85  Rotation  L17
# x =  68  Current point now = 68  increment = 0
#
# Current point  68  Rotation  L41
# x =  27  Current point now = 27  increment = 0
#
# Current point  27  Rotation  L41
# x =  -14  Current point now = 86  increment = 1
#
# Current point  86  Rotation  L26
# x =  60  Current point now = 60  increment = 0
#
# Current point  60  Rotation  L12
# x =  48  Current point now = 48  increment = 0
#
# Current point  48  Rotation  R3
# x =  51  Current point now = 51  increment = 0
#
# Current point  51  Rotation  R23
# x =  74  Current point now = 74  increment = 0
#
# Current point  74  Rotation  R39
# x =  113  Current point now = 13  increment = 1
#
# Current point  13  Rotation  L35
# x =  -22  Current point now = 78  increment = 1
#
# Current point  78  Rotation  L39
# x =  39  Current point now = 39  increment = 0
#
# Current point  39  Rotation  L34
# x =  5  Current point now = 5  increment = 0
#
# Current point  5  Rotation  L47
# x =  -42  Current point now = 58  increment = 1
#
# Current point  58  Rotation  L28
# x =  30  Current point now = 30  increment = 0
#
# Current point  30  Rotation  R44
# x =  74  Current point now = 74  increment = 0
#
# Current point  74  Rotation  L17
# x =  57  Current point now = 57  increment = 0
#
# Current point  57  Rotation  R35
# x =  92  Current point now = 92  increment = 0
#
# Current point  92  Rotation  R44
# x =  136  Current point now = 36  increment = 1
#
# Current point  36  Rotation  L49
# x =  -13  Current point now = 87  increment = 1
#
# Current point  87  Rotation  L75
# x =  12  Current point now = 12  increment = 0
#
# Current point  12  Rotation  L89
# x =  -77  Current point now = 23  increment = 1
#
# Current point  23  Rotation  R94
# x =  117  Current point now = 17  increment = 1
#
# Current point  17  Rotation  R71
# x =  88  Current point now = 88  increment = 0
#
# Current point  88  Rotation  L98
# x =  -10  Current point now = 90  increment = 1
#
# Current point  90  Rotation  L90
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L91
# x =  9  Current point now = 9  increment = 0
#
# Current point  9  Rotation  L58
# x =  -49  Current point now = 51  increment = 1
#
# Current point  51  Rotation  R49
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R35
# x =  35  Current point now = 35  increment = 0
#
# Current point  35  Rotation  R65
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L71
# x =  29  Current point now = 29  increment = 0
#
# Current point  29  Rotation  R91
# x =  120  Current point now = 20  increment = 1
#
# Current point  20  Rotation  L7
# x =  13  Current point now = 13  increment = 0
#
# Current point  13  Rotation  R61
# x =  74  Current point now = 74  increment = 0
#
# Current point  74  Rotation  R66
# x =  140  Current point now = 40  increment = 1
#
# Current point  40  Rotation  L28
# x =  12  Current point now = 12  increment = 0
#
# Current point  12  Rotation  L12
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R59
# x =  59  Current point now = 59  increment = 0
#
# Current point  59  Rotation  L88
# x =  -29  Current point now = 71  increment = 1
#
# Current point  71  Rotation  L71
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L75
# x =  25  Current point now = 25  increment = 0
#
# Current point  25  Rotation  L24
# x =  1  Current point now = 1  increment = 0
#
# Current point  1  Rotation  L25
# x =  -24  Current point now = 76  increment = 1
#
# Current point  76  Rotation  L44
# x =  32  Current point now = 32  increment = 0
#
# Current point  32  Rotation  R68
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R69
# x =  69  Current point now = 69  increment = 0
#
# Current point  69  Rotation  L99
# x =  -30  Current point now = 70  increment = 1
#
# Current point  70  Rotation  R62
# x =  132  Current point now = 32  increment = 1
#
# Current point  32  Rotation  L84
# x =  -52  Current point now = 48  increment = 1
#
# Current point  48  Rotation  R52
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R23
# x =  23  Current point now = 23  increment = 0
#
# Current point  23  Rotation  L23
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R69
# x =  69  Current point now = 69  increment = 0
#
# Current point  69  Rotation  R96
# x =  165  Current point now = 65  increment = 1
#
# Current point  65  Rotation  R35
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R45
# x =  45  Current point now = 45  increment = 0
#
# Current point  45  Rotation  R55
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R39
# x =  39  Current point now = 39  increment = 0
#
# Current point  39  Rotation  R61
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L1
# x =  99  Current point now = 99  increment = 0
#
# Current point  99  Rotation  L20
# x =  79  Current point now = 79  increment = 0
#
# Current point  79  Rotation  R70
# x =  149  Current point now = 49  increment = 1
#
# Current point  49  Rotation  L49
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L97
# x =  3  Current point now = 3  increment = 0
#
# Current point  3  Rotation  R97
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R36
# x =  36  Current point now = 36  increment = 0
#
# Current point  36  Rotation  R68
# x =  104  Current point now = 4  increment = 1
#
# Current point  4  Rotation  L4
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R22
# x =  22  Current point now = 22  increment = 0
#
# Current point  22  Rotation  R61
# x =  83  Current point now = 83  increment = 0
#
# Current point  83  Rotation  R22
# x =  105  Current point now = 5  increment = 1
#
# Current point  5  Rotation  R95
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R63
# x =  63  Current point now = 63  increment = 0
#
# Current point  63  Rotation  L82
# x =  -19  Current point now = 81  increment = 1
#
# Current point  81  Rotation  R45
# x =  126  Current point now = 26  increment = 1
#
# Current point  26  Rotation  R9
# x =  35  Current point now = 35  increment = 0
#
# Current point  35  Rotation  R83
# x =  118  Current point now = 18  increment = 1
#
# Current point  18  Rotation  R86
# x =  104  Current point now = 4  increment = 1
#
# Current point  4  Rotation  R96
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R49
# x =  49  Current point now = 49  increment = 0
#
# Current point  49  Rotation  L49
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L48
# x =  52  Current point now = 52  increment = 0
#
# Current point  52  Rotation  L68
# x =  -16  Current point now = 84  increment = 1
#
# Current point  84  Rotation  R150
# x =  234  Current point now = 34  increment = 2
#
# Current point  34  Rotation  R66
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R89
# x =  89  Current point now = 89  increment = 0
#
# Current point  89  Rotation  L589
# x =  -500  Current point now = 0  increment = 6
#
# Current point  0  Rotation  R85
# x =  85  Current point now = 85  increment = 0
#
# Current point  85  Rotation  R15
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L70
# x =  30  Current point now = 30  increment = 0
#
# Current point  30  Rotation  R70
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L95
# x =  5  Current point now = 5  increment = 0
#
# Current point  5  Rotation  L305
# x =  -300  Current point now = 0  increment = 4
#
# Current point  0  Rotation  R28
# x =  28  Current point now = 28  increment = 0
#
# Current point  28  Rotation  R72
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R58
# x =  58  Current point now = 58  increment = 0
#
# Current point  58  Rotation  L47
# x =  11  Current point now = 11  increment = 0
#
# Current point  11  Rotation  R50
# x =  61  Current point now = 61  increment = 0
#
# Current point  61  Rotation  L61
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L25
# x =  75  Current point now = 75  increment = 0
#
# Current point  75  Rotation  R25
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L43
# x =  57  Current point now = 57  increment = 0
#
# Current point  57  Rotation  L34
# x =  23  Current point now = 23  increment = 0
#
# Current point  23  Rotation  L23
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R95
# x =  95  Current point now = 95  increment = 0
#
# Current point  95  Rotation  R84
# x =  179  Current point now = 79  increment = 1
#
# Current point  79  Rotation  R821
# x =  900  Current point now = 0  increment = 10
#
# Current point  0  Rotation  R83
# x =  83  Current point now = 83  increment = 0
#
# Current point  83  Rotation  L25
# x =  58  Current point now = 58  increment = 0
#
# Current point  58  Rotation  R90
# x =  148  Current point now = 48  increment = 1
#
# Current point  48  Rotation  R366
# x =  414  Current point now = 14  increment = 4
#
# Current point  14  Rotation  L639
# x =  -625  Current point now = 75  increment = 7
#
# Current point  75  Rotation  R25
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R70
# x =  70  Current point now = 70  increment = 0
#
# Current point  70  Rotation  R22
# x =  92  Current point now = 92  increment = 0
#
# Current point  92  Rotation  L75
# x =  17  Current point now = 17  increment = 0
#
# Current point  17  Rotation  L117
# x =  -100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L77
# x =  23  Current point now = 23  increment = 0
#
# Current point  23  Rotation  R67
# x =  90  Current point now = 90  increment = 0
#
# Current point  90  Rotation  L490
# x =  -400  Current point now = 0  increment = 5
#
# Current point  0  Rotation  R23
# x =  23  Current point now = 23  increment = 0
#
# Current point  23  Rotation  R277
# x =  300  Current point now = 0  increment = 4
#
# Current point  0  Rotation  L55
# x =  45  Current point now = 45  increment = 0
#
# Current point  45  Rotation  L25
# x =  20  Current point now = 20  increment = 0
#
# Current point  20  Rotation  L20
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L9
# x =  91  Current point now = 91  increment = 0
#
# Current point  91  Rotation  R66
# x =  157  Current point now = 57  increment = 1
#
# Current point  57  Rotation  L34
# x =  23  Current point now = 23  increment = 0
#
# Current point  23  Rotation  R83
# x =  106  Current point now = 6  increment = 1
#
# Current point  6  Rotation  R82
# x =  88  Current point now = 88  increment = 0
#
# Current point  88  Rotation  L76
# x =  12  Current point now = 12  increment = 0
#
# Current point  12  Rotation  L18
# x =  -6  Current point now = 94  increment = 1
#
# Current point  94  Rotation  L54
# x =  40  Current point now = 40  increment = 0
#
# Current point  40  Rotation  R60
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L305
# x =  -205  Current point now = 95  increment = 3
#
# Current point  95  Rotation  L87
# x =  8  Current point now = 8  increment = 0
#
# Current point  8  Rotation  R81
# x =  89  Current point now = 89  increment = 0
#
# Current point  89  Rotation  L71
# x =  18  Current point now = 18  increment = 0
#
# Current point  18  Rotation  R4
# x =  22  Current point now = 22  increment = 0
#
# Current point  22  Rotation  L22
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R255
# x =  255  Current point now = 55  increment = 2
#
# Current point  55  Rotation  L655
# x =  -600  Current point now = 0  increment = 7
#
# Current point  0  Rotation  L91
# x =  9  Current point now = 9  increment = 0
#
# Current point  9  Rotation  L9
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L398
# x =  -298  Current point now = 2  increment = 3
#
# Current point  2  Rotation  L40
# x =  -38  Current point now = 62  increment = 1
#
# Current point  62  Rotation  R56
# x =  118  Current point now = 18  increment = 1
#
# Current point  18  Rotation  R13
# x =  31  Current point now = 31  increment = 0
#
# Current point  31  Rotation  L88
# x =  -57  Current point now = 43  increment = 1
#
# Current point  43  Rotation  R73
# x =  116  Current point now = 16  increment = 1
#
# Current point  16  Rotation  L55
# x =  -39  Current point now = 61  increment = 1
#
# Current point  61  Rotation  L61
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L87
# x =  13  Current point now = 13  increment = 0
#
# Current point  13  Rotation  R405
# x =  418  Current point now = 18  increment = 4
#
# Current point  18  Rotation  R27
# x =  45  Current point now = 45  increment = 0
#
# Current point  45  Rotation  L45
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L80
# x =  20  Current point now = 20  increment = 0
#
# Current point  20  Rotation  R80
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L72
# x =  28  Current point now = 28  increment = 0
#
# Current point  28  Rotation  L96
# x =  -68  Current point now = 32  increment = 1
#
# Current point  32  Rotation  R68
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R60
# x =  60  Current point now = 60  increment = 0
#
# Current point  60  Rotation  R825
# x =  885  Current point now = 85  increment = 8
#
# Current point  85  Rotation  R8
# x =  93  Current point now = 93  increment = 0
#
# Current point  93  Rotation  R207
# x =  300  Current point now = 0  increment = 4
#
# Current point  0  Rotation  R96
# x =  96  Current point now = 96  increment = 0
#
# Current point  96  Rotation  L55
# x =  41  Current point now = 41  increment = 0
#
# Current point  41  Rotation  R59
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L71
# x =  29  Current point now = 29  increment = 0
#
# Current point  29  Rotation  R98
# x =  127  Current point now = 27  increment = 1
#
# Current point  27  Rotation  R3
# x =  30  Current point now = 30  increment = 0
#
# Current point  30  Rotation  L230
# x =  -200  Current point now = 0  increment = 3
#
# Current point  0  Rotation  R50
# x =  50  Current point now = 50  increment = 0
#
# Current point  50  Rotation  L50
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L729
# x =  -629  Current point now = 71  increment = 7
#
# Current point  71  Rotation  R15
# x =  86  Current point now = 86  increment = 0
#
# Current point  86  Rotation  R11
# x =  97  Current point now = 97  increment = 0
#
# Current point  97  Rotation  L86
# x =  11  Current point now = 11  increment = 0
#
# Current point  11  Rotation  R62
# x =  73  Current point now = 73  increment = 0
#
# Current point  73  Rotation  R27
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L6
# x =  94  Current point now = 94  increment = 0
#
# Current point  94  Rotation  L94
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R54
# x =  54  Current point now = 54  increment = 0
#
# Current point  54  Rotation  R51
# x =  105  Current point now = 5  increment = 1
#
# Current point  5  Rotation  L5
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L88
# x =  12  Current point now = 12  increment = 0
#
# Current point  12  Rotation  L89
# x =  -77  Current point now = 23  increment = 1
#
# Current point  23  Rotation  L123
# x =  -100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R88
# x =  88  Current point now = 88  increment = 0
#
# Current point  88  Rotation  L349
# x =  -261  Current point now = 39  increment = 3
#
# Current point  39  Rotation  R42
# x =  81  Current point now = 81  increment = 0
#
# Current point  81  Rotation  L51
# x =  30  Current point now = 30  increment = 0
#
# Current point  30  Rotation  L88
# x =  -58  Current point now = 42  increment = 1
#
# Current point  42  Rotation  R15
# x =  57  Current point now = 57  increment = 0
#
# Current point  57  Rotation  R44
# x =  101  Current point now = 1  increment = 1
#
# Current point  1  Rotation  L94
# x =  -93  Current point now = 7  increment = 1
#
# Current point  7  Rotation  L29
# x =  -22  Current point now = 78  increment = 1
#
# Current point  78  Rotation  L78
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R49
# x =  49  Current point now = 49  increment = 0
#
# Current point  49  Rotation  L86
# x =  -37  Current point now = 63  increment = 1
#
# Current point  63  Rotation  R85
# x =  148  Current point now = 48  increment = 1
#
# Current point  48  Rotation  L36
# x =  12  Current point now = 12  increment = 0
#
# Current point  12  Rotation  R54
# x =  66  Current point now = 66  increment = 0
#
# Current point  66  Rotation  L146
# x =  -80  Current point now = 20  increment = 1
#
# Current point  20  Rotation  L20
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R6
# x =  6  Current point now = 6  increment = 0
#
# Current point  6  Rotation  R94
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L35
# x =  65  Current point now = 65  increment = 0
#
# Current point  65  Rotation  L46
# x =  19  Current point now = 19  increment = 0
#
# Current point  19  Rotation  L17
# x =  2  Current point now = 2  increment = 0
#
# Current point  2  Rotation  R23
# x =  25  Current point now = 25  increment = 0
#
# Current point  25  Rotation  R74
# x =  99  Current point now = 99  increment = 0
#
# Current point  99  Rotation  L99
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R95
# x =  95  Current point now = 95  increment = 0
#
# Current point  95  Rotation  L26
# x =  69  Current point now = 69  increment = 0
#
# Current point  69  Rotation  L47
# x =  22  Current point now = 22  increment = 0
#
# Current point  22  Rotation  R52
# x =  74  Current point now = 74  increment = 0
#
# Current point  74  Rotation  L74
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L96
# x =  4  Current point now = 4  increment = 0
#
# Current point  4  Rotation  L51
# x =  -47  Current point now = 53  increment = 1
#
# Current point  53  Rotation  R47
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L239
# x =  -139  Current point now = 61  increment = 2
#
# Current point  61  Rotation  R48
# x =  109  Current point now = 9  increment = 1
#
# Current point  9  Rotation  R186
# x =  195  Current point now = 95  increment = 1
#
# Current point  95  Rotation  L44
# x =  51  Current point now = 51  increment = 0
#
# Current point  51  Rotation  L18
# x =  33  Current point now = 33  increment = 0
#
# Current point  33  Rotation  L33
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R83
# x =  83  Current point now = 83  increment = 0
#
# Current point  83  Rotation  R3
# x =  86  Current point now = 86  increment = 0
#
# Current point  86  Rotation  R561
# x =  647  Current point now = 47  increment = 6
#
# Current point  47  Rotation  R86
# x =  133  Current point now = 33  increment = 1
#
# Current point  33  Rotation  L933
# x =  -900  Current point now = 0  increment = 10
#
# Current point  0  Rotation  R527
# x =  527  Current point now = 27  increment = 5
#
# Current point  27  Rotation  R88
# x =  115  Current point now = 15  increment = 1
#
# Current point  15  Rotation  R85
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L186
# x =  -86  Current point now = 14  increment = 1
#
# Current point  14  Rotation  R86
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L1
# x =  99  Current point now = 99  increment = 0
#
# Current point  99  Rotation  L99
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L3
# x =  97  Current point now = 97  increment = 0
#
# Current point  97  Rotation  L97
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R68
# x =  68  Current point now = 68  increment = 0
#
# Current point  68  Rotation  L81
# x =  -13  Current point now = 87  increment = 1
#
# Current point  87  Rotation  L50
# x =  37  Current point now = 37  increment = 0
#
# Current point  37  Rotation  R360
# x =  397  Current point now = 97  increment = 3
#
# Current point  97  Rotation  L46
# x =  51  Current point now = 51  increment = 0
#
# Current point  51  Rotation  R70
# x =  121  Current point now = 21  increment = 1
#
# Current point  21  Rotation  R81
# x =  102  Current point now = 2  increment = 1
#
# Current point  2  Rotation  L2
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L87
# x =  13  Current point now = 13  increment = 0
#
# Current point  13  Rotation  R92
# x =  105  Current point now = 5  increment = 1
#
# Current point  5  Rotation  R95
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R39
# x =  39  Current point now = 39  increment = 0
#
# Current point  39  Rotation  R4
# x =  43  Current point now = 43  increment = 0
#
# Current point  43  Rotation  L90
# x =  -47  Current point now = 53  increment = 1
#
# Current point  53  Rotation  R603
# x =  656  Current point now = 56  increment = 6
#
# Current point  56  Rotation  R467
# x =  523  Current point now = 23  increment = 5
#
# Current point  23  Rotation  R36
# x =  59  Current point now = 59  increment = 0
#
# Current point  59  Rotation  L24
# x =  35  Current point now = 35  increment = 0
#
# Current point  35  Rotation  L35
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R12
# x =  12  Current point now = 12  increment = 0
#
# Current point  12  Rotation  L46
# x =  -34  Current point now = 66  increment = 1
#
# Current point  66  Rotation  L80
# x =  -14  Current point now = 86  increment = 1
#
# Current point  86  Rotation  R65
# x =  151  Current point now = 51  increment = 1
#
# Current point  51  Rotation  R28
# x =  79  Current point now = 79  increment = 0
#
# Current point  79  Rotation  R51
# x =  130  Current point now = 30  increment = 1
#
# Current point  30  Rotation  R70
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R83
# x =  83  Current point now = 83  increment = 0
#
# Current point  83  Rotation  L26
# x =  57  Current point now = 57  increment = 0
#
# Current point  57  Rotation  L431
# x =  -374  Current point now = 26  increment = 4
#
# Current point  26  Rotation  R818
# x =  844  Current point now = 44  increment = 8
#
# Current point  44  Rotation  R114
# x =  158  Current point now = 58  increment = 1
#
# Current point  58  Rotation  L58
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L29
# x =  71  Current point now = 71  increment = 0
#
# Current point  71  Rotation  R29
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L65
# x =  35  Current point now = 35  increment = 0
#
# Current point  35  Rotation  R23
# x =  58  Current point now = 58  increment = 0
#
# Current point  58  Rotation  R22
# x =  80  Current point now = 80  increment = 0
#
# Current point  80  Rotation  R343
# x =  423  Current point now = 23  increment = 4
#
# Current point  23  Rotation  L593
# x =  -570  Current point now = 30  increment = 6
#
# Current point  30  Rotation  L56
# x =  -26  Current point now = 74  increment = 1
#
# Current point  74  Rotation  L174
# x =  -100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L65
# x =  35  Current point now = 35  increment = 0
#
# Current point  35  Rotation  R65
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L79
# x =  21  Current point now = 21  increment = 0
#
# Current point  21  Rotation  R19
# x =  40  Current point now = 40  increment = 0
#
# Current point  40  Rotation  R50
# x =  90  Current point now = 90  increment = 0
#
# Current point  90  Rotation  R12
# x =  102  Current point now = 2  increment = 1
#
# Current point  2  Rotation  R90
# x =  92  Current point now = 92  increment = 0
#
# Current point  92  Rotation  L92
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R89
# x =  89  Current point now = 89  increment = 0
#
# Current point  89  Rotation  R11
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L20
# x =  80  Current point now = 80  increment = 0
#
# Current point  80  Rotation  L80
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L88
# x =  12  Current point now = 12  increment = 0
#
# Current point  12  Rotation  R98
# x =  110  Current point now = 10  increment = 1
#
# Current point  10  Rotation  L10
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L540
# x =  -440  Current point now = 60  increment = 5
#
# Current point  60  Rotation  L901
# x =  -841  Current point now = 59  increment = 9
#
# Current point  59  Rotation  R41
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R57
# x =  57  Current point now = 57  increment = 0
#
# Current point  57  Rotation  L27
# x =  30  Current point now = 30  increment = 0
#
# Current point  30  Rotation  R12
# x =  42  Current point now = 42  increment = 0
#
# Current point  42  Rotation  L589
# x =  -547  Current point now = 53  increment = 6
#
# Current point  53  Rotation  L35
# x =  18  Current point now = 18  increment = 0
#
# Current point  18  Rotation  L218
# x =  -200  Current point now = 0  increment = 3
#
# Current point  0  Rotation  L79
# x =  21  Current point now = 21  increment = 0
#
# Current point  21  Rotation  R79
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L578
# x =  -478  Current point now = 22  increment = 5
#
# Current point  22  Rotation  R12
# x =  34  Current point now = 34  increment = 0
#
# Current point  34  Rotation  R16
# x =  50  Current point now = 50  increment = 0
#
# Current point  50  Rotation  R71
# x =  121  Current point now = 21  increment = 1
#
# Current point  21  Rotation  L421
# x =  -400  Current point now = 0  increment = 5
#
# Current point  0  Rotation  L18
# x =  82  Current point now = 82  increment = 0
#
# Current point  82  Rotation  L82
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R37
# x =  37  Current point now = 37  increment = 0
#
# Current point  37  Rotation  R63
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L50
# x =  50  Current point now = 50  increment = 0
#
# Current point  50  Rotation  R50
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R71
# x =  71  Current point now = 71  increment = 0
#
# Current point  71  Rotation  R71
# x =  142  Current point now = 42  increment = 1
#
# Current point  42  Rotation  R58
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R34
# x =  34  Current point now = 34  increment = 0
#
# Current point  34  Rotation  L534
# x =  -500  Current point now = 0  increment = 6
#
# Current point  0  Rotation  L390
# x =  -290  Current point now = 10  increment = 3
#
# Current point  10  Rotation  R862
# x =  872  Current point now = 72  increment = 8
#
# Current point  72  Rotation  L204
# x =  -132  Current point now = 68  increment = 2
#
# Current point  68  Rotation  R70
# x =  138  Current point now = 38  increment = 1
#
# Current point  38  Rotation  R97
# x =  135  Current point now = 35  increment = 1
#
# Current point  35  Rotation  L35
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L333
# x =  -233  Current point now = 67  increment = 3
#
# Current point  67  Rotation  R430
# x =  497  Current point now = 97  increment = 4
#
# Current point  97  Rotation  L59
# x =  38  Current point now = 38  increment = 0
#
# Current point  38  Rotation  R7
# x =  45  Current point now = 45  increment = 0
#
# Current point  45  Rotation  L893
# x =  -848  Current point now = 52  increment = 9
#
# Current point  52  Rotation  L33
# x =  19  Current point now = 19  increment = 0
#
# Current point  19  Rotation  L19
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L35
# x =  65  Current point now = 65  increment = 0
#
# Current point  65  Rotation  R35
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R43
# x =  43  Current point now = 43  increment = 0
#
# Current point  43  Rotation  L43
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R63
# x =  63  Current point now = 63  increment = 0
#
# Current point  63  Rotation  L63
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R88
# x =  88  Current point now = 88  increment = 0
#
# Current point  88  Rotation  L188
# x =  -100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L32
# x =  68  Current point now = 68  increment = 0
#
# Current point  68  Rotation  R84
# x =  152  Current point now = 52  increment = 1
#
# Current point  52  Rotation  L52
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R69
# x =  69  Current point now = 69  increment = 0
#
# Current point  69  Rotation  R31
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L445
# x =  -345  Current point now = 55  increment = 4
#
# Current point  55  Rotation  L33
# x =  22  Current point now = 22  increment = 0
#
# Current point  22  Rotation  L88
# x =  -66  Current point now = 34  increment = 1
#
# Current point  34  Rotation  R201
# x =  235  Current point now = 35  increment = 2
#
# Current point  35  Rotation  L35
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L30
# x =  70  Current point now = 70  increment = 0
#
# Current point  70  Rotation  R30
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R26
# x =  26  Current point now = 26  increment = 0
#
# Current point  26  Rotation  L82
# x =  -56  Current point now = 44  increment = 1
#
# Current point  44  Rotation  L638
# x =  -594  Current point now = 6  increment = 6
#
# Current point  6  Rotation  R16
# x =  22  Current point now = 22  increment = 0
#
# Current point  22  Rotation  L62
# x =  -40  Current point now = 60  increment = 1
#
# Current point  60  Rotation  L60
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R16
# x =  16  Current point now = 16  increment = 0
#
# Current point  16  Rotation  L42
# x =  -26  Current point now = 74  increment = 1
#
# Current point  74  Rotation  R36
# x =  110  Current point now = 10  increment = 1
#
# Current point  10  Rotation  L65
# x =  -55  Current point now = 45  increment = 1
#
# Current point  45  Rotation  L63
# x =  -18  Current point now = 82  increment = 1
#
# Current point  82  Rotation  R775
# x =  857  Current point now = 57  increment = 8
#
# Current point  57  Rotation  L57
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L4
# x =  96  Current point now = 96  increment = 0
#
# Current point  96  Rotation  R1
# x =  97  Current point now = 97  increment = 0
#
# Current point  97  Rotation  L21
# x =  76  Current point now = 76  increment = 0
#
# Current point  76  Rotation  R77
# x =  153  Current point now = 53  increment = 1
#
# Current point  53  Rotation  R47
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L62
# x =  38  Current point now = 38  increment = 0
#
# Current point  38  Rotation  R44
# x =  82  Current point now = 82  increment = 0
#
# Current point  82  Rotation  R29
# x =  111  Current point now = 11  increment = 1
#
# Current point  11  Rotation  L17
# x =  -6  Current point now = 94  increment = 1
#
# Current point  94  Rotation  R80
# x =  174  Current point now = 74  increment = 1
#
# Current point  74  Rotation  R67
# x =  141  Current point now = 41  increment = 1
#
# Current point  41  Rotation  L79
# x =  -38  Current point now = 62  increment = 1
#
# Current point  62  Rotation  L6
# x =  56  Current point now = 56  increment = 0
#
# Current point  56  Rotation  R44
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R669
# x =  669  Current point now = 69  increment = 6
#
# Current point  69  Rotation  R46
# x =  115  Current point now = 15  increment = 1
#
# Current point  15  Rotation  L15
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L57
# x =  43  Current point now = 43  increment = 0
#
# Current point  43  Rotation  L25
# x =  18  Current point now = 18  increment = 0
#
# Current point  18  Rotation  R14
# x =  32  Current point now = 32  increment = 0
#
# Current point  32  Rotation  L47
# x =  -15  Current point now = 85  increment = 1
#
# Current point  85  Rotation  R415
# x =  500  Current point now = 0  increment = 6
#
# Current point  0  Rotation  L81
# x =  19  Current point now = 19  increment = 0
#
# Current point  19  Rotation  L19
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L23
# x =  77  Current point now = 77  increment = 0
#
# Current point  77  Rotation  R263
# x =  340  Current point now = 40  increment = 3
#
# Current point  40  Rotation  L55
# x =  -15  Current point now = 85  increment = 1
#
# Current point  85  Rotation  L433
# x =  -348  Current point now = 52  increment = 4
#
# Current point  52  Rotation  L49
# x =  3  Current point now = 3  increment = 0
#
# Current point  3  Rotation  R1
# x =  4  Current point now = 4  increment = 0
#
# Current point  4  Rotation  L1
# x =  3  Current point now = 3  increment = 0
#
# Current point  3  Rotation  L95
# x =  -92  Current point now = 8  increment = 1
#
# Current point  8  Rotation  R99
# x =  107  Current point now = 7  increment = 1
#
# Current point  7  Rotation  L31
# x =  -24  Current point now = 76  increment = 1
#
# Current point  76  Rotation  L18
# x =  58  Current point now = 58  increment = 0
#
# Current point  58  Rotation  R90
# x =  148  Current point now = 48  increment = 1
#
# Current point  48  Rotation  R588
# x =  636  Current point now = 36  increment = 6
#
# Current point  36  Rotation  R54
# x =  90  Current point now = 90  increment = 0
#
# Current point  90  Rotation  L94
# x =  -4  Current point now = 96  increment = 1
#
# Current point  96  Rotation  L96
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L46
# x =  54  Current point now = 54  increment = 0
#
# Current point  54  Rotation  R183
# x =  237  Current point now = 37  increment = 2
#
# Current point  37  Rotation  L437
# x =  -400  Current point now = 0  increment = 5
#
# Current point  0  Rotation  R803
# x =  803  Current point now = 3  increment = 8
#
# Current point  3  Rotation  L59
# x =  -56  Current point now = 44  increment = 1
#
# Current point  44  Rotation  R95
# x =  139  Current point now = 39  increment = 1
#
# Current point  39  Rotation  L46
# x =  -7  Current point now = 93  increment = 1
#
# Current point  93  Rotation  L13
# x =  80  Current point now = 80  increment = 0
#
# Current point  80  Rotation  R20
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L60
# x =  40  Current point now = 40  increment = 0
#
# Current point  40  Rotation  R92
# x =  132  Current point now = 32  increment = 1
#
# Current point  32  Rotation  L14
# x =  18  Current point now = 18  increment = 0
#
# Current point  18  Rotation  L18
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L134
# x =  -34  Current point now = 66  increment = 1
#
# Current point  66  Rotation  L66
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R73
# x =  73  Current point now = 73  increment = 0
#
# Current point  73  Rotation  R11
# x =  84  Current point now = 84  increment = 0
#
# Current point  84  Rotation  L28
# x =  56  Current point now = 56  increment = 0
#
# Current point  56  Rotation  L56
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R15
# x =  15  Current point now = 15  increment = 0
#
# Current point  15  Rotation  R7
# x =  22  Current point now = 22  increment = 0
#
# Current point  22  Rotation  R24
# x =  46  Current point now = 46  increment = 0
#
# Current point  46  Rotation  L246
# x =  -200  Current point now = 0  increment = 3
#
# Current point  0  Rotation  L830
# x =  -730  Current point now = 70  increment = 8
#
# Current point  70  Rotation  R25
# x =  95  Current point now = 95  increment = 0
#
# Current point  95  Rotation  R5
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L58
# x =  42  Current point now = 42  increment = 0
#
# Current point  42  Rotation  L8
# x =  34  Current point now = 34  increment = 0
#
# Current point  34  Rotation  R24
# x =  58  Current point now = 58  increment = 0
#
# Current point  58  Rotation  L58
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R998
# x =  998  Current point now = 98  increment = 9
#
# Current point  98  Rotation  R4
# x =  102  Current point now = 2  increment = 1
#
# Current point  2  Rotation  R998
# x =  1000  Current point now = 0  increment = 11
#
# Current point  0  Rotation  L99
# x =  1  Current point now = 1  increment = 0
#
# Current point  1  Rotation  R9
# x =  10  Current point now = 10  increment = 0
#
# Current point  10  Rotation  R790
# x =  800  Current point now = 0  increment = 9
#
# Current point  0  Rotation  L51
# x =  49  Current point now = 49  increment = 0
#
# Current point  49  Rotation  R39
# x =  88  Current point now = 88  increment = 0
#
# Current point  88  Rotation  L49
# x =  39  Current point now = 39  increment = 0
#
# Current point  39  Rotation  L339
# x =  -300  Current point now = 0  increment = 4
#
# Current point  0  Rotation  L852
# x =  -752  Current point now = 48  increment = 8
#
# Current point  48  Rotation  L69
# x =  -21  Current point now = 79  increment = 1
#
# Current point  79  Rotation  L70
# x =  9  Current point now = 9  increment = 0
#
# Current point  9  Rotation  R49
# x =  58  Current point now = 58  increment = 0
#
# Current point  58  Rotation  L26
# x =  32  Current point now = 32  increment = 0
#
# Current point  32  Rotation  R70
# x =  102  Current point now = 2  increment = 1
#
# Current point  2  Rotation  R13
# x =  15  Current point now = 15  increment = 0
#
# Current point  15  Rotation  R85
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L21
# x =  79  Current point now = 79  increment = 0
#
# Current point  79  Rotation  L13
# x =  66  Current point now = 66  increment = 0
#
# Current point  66  Rotation  L65
# x =  1  Current point now = 1  increment = 0
#
# Current point  1  Rotation  L60
# x =  -59  Current point now = 41  increment = 1
#
# Current point  41  Rotation  L41
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R915
# x =  915  Current point now = 15  increment = 9
#
# Current point  15  Rotation  L102
# x =  -87  Current point now = 13  increment = 1
#
# Current point  13  Rotation  R64
# x =  77  Current point now = 77  increment = 0
#
# Current point  77  Rotation  R85
# x =  162  Current point now = 62  increment = 1
#
# Current point  62  Rotation  R6
# x =  68  Current point now = 68  increment = 0
#
# Current point  68  Rotation  R17
# x =  85  Current point now = 85  increment = 0
#
# Current point  85  Rotation  L61
# x =  24  Current point now = 24  increment = 0
#
# Current point  24  Rotation  R689
# x =  713  Current point now = 13  increment = 7
#
# Current point  13  Rotation  L13
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R778
# x =  778  Current point now = 78  increment = 7
#
# Current point  78  Rotation  L13
# x =  65  Current point now = 65  increment = 0
#
# Current point  65  Rotation  L22
# x =  43  Current point now = 43  increment = 0
#
# Current point  43  Rotation  R78
# x =  121  Current point now = 21  increment = 1
#
# Current point  21  Rotation  R79
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L40
# x =  60  Current point now = 60  increment = 0
#
# Current point  60  Rotation  L75
# x =  -15  Current point now = 85  increment = 1
#
# Current point  85  Rotation  L491
# x =  -406  Current point now = 94  increment = 5
#
# Current point  94  Rotation  R48
# x =  142  Current point now = 42  increment = 1
#
# Current point  42  Rotation  R58
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L80
# x =  20  Current point now = 20  increment = 0
#
# Current point  20  Rotation  L20
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R51
# x =  51  Current point now = 51  increment = 0
#
# Current point  51  Rotation  L51
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R92
# x =  92  Current point now = 92  increment = 0
#
# Current point  92  Rotation  R7
# x =  99  Current point now = 99  increment = 0
#
# Current point  99  Rotation  R29
# x =  128  Current point now = 28  increment = 1
#
# Current point  28  Rotation  R47
# x =  75  Current point now = 75  increment = 0
#
# Current point  75  Rotation  R6
# x =  81  Current point now = 81  increment = 0
#
# Current point  81  Rotation  L81
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R93
# x =  93  Current point now = 93  increment = 0
#
# Current point  93  Rotation  L775
# x =  -682  Current point now = 18  increment = 7
#
# Current point  18  Rotation  L98
# x =  -80  Current point now = 20  increment = 1
#
# Current point  20  Rotation  R34
# x =  54  Current point now = 54  increment = 0
#
# Current point  54  Rotation  L16
# x =  38  Current point now = 38  increment = 0
#
# Current point  38  Rotation  L65
# x =  -27  Current point now = 73  increment = 1
#
# Current point  73  Rotation  L73
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R66
# x =  66  Current point now = 66  increment = 0
#
# Current point  66  Rotation  R34
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R64
# x =  64  Current point now = 64  increment = 0
#
# Current point  64  Rotation  L64
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R63
# x =  63  Current point now = 63  increment = 0
#
# Current point  63  Rotation  R537
# x =  600  Current point now = 0  increment = 7
#
# Current point  0  Rotation  L19
# x =  81  Current point now = 81  increment = 0
#
# Current point  81  Rotation  R19
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R772
# x =  772  Current point now = 72  increment = 7
#
# Current point  72  Rotation  L72
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R15
# x =  15  Current point now = 15  increment = 0
#
# Current point  15  Rotation  R785
# x =  800  Current point now = 0  increment = 9
#
# Current point  0  Rotation  L76
# x =  24  Current point now = 24  increment = 0
#
# Current point  24  Rotation  R76
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R83
# x =  83  Current point now = 83  increment = 0
#
# Current point  83  Rotation  R17
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R94
# x =  94  Current point now = 94  increment = 0
#
# Current point  94  Rotation  R54
# x =  148  Current point now = 48  increment = 1
#
# Current point  48  Rotation  R70
# x =  118  Current point now = 18  increment = 1
#
# Current point  18  Rotation  R303
# x =  321  Current point now = 21  increment = 3
#
# Current point  21  Rotation  R19
# x =  40  Current point now = 40  increment = 0
#
# Current point  40  Rotation  R60
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L90
# x =  10  Current point now = 10  increment = 0
#
# Current point  10  Rotation  L38
# x =  -28  Current point now = 72  increment = 1
#
# Current point  72  Rotation  L72
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R24
# x =  24  Current point now = 24  increment = 0
#
# Current point  24  Rotation  R43
# x =  67  Current point now = 67  increment = 0
#
# Current point  67  Rotation  L67
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R42
# x =  42  Current point now = 42  increment = 0
#
# Current point  42  Rotation  R46
# x =  88  Current point now = 88  increment = 0
#
# Current point  88  Rotation  R12
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R53
# x =  53  Current point now = 53  increment = 0
#
# Current point  53  Rotation  R217
# x =  270  Current point now = 70  increment = 2
#
# Current point  70  Rotation  R493
# x =  563  Current point now = 63  increment = 5
#
# Current point  63  Rotation  R49
# x =  112  Current point now = 12  increment = 1
#
# Current point  12  Rotation  R60
# x =  72  Current point now = 72  increment = 0
#
# Current point  72  Rotation  R85
# x =  157  Current point now = 57  increment = 1
#
# Current point  57  Rotation  L57
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R88
# x =  88  Current point now = 88  increment = 0
#
# Current point  88  Rotation  L43
# x =  45  Current point now = 45  increment = 0
#
# Current point  45  Rotation  L89
# x =  -44  Current point now = 56  increment = 1
#
# Current point  56  Rotation  R18
# x =  74  Current point now = 74  increment = 0
#
# Current point  74  Rotation  L994
# x =  -920  Current point now = 80  increment = 10
#
# Current point  80  Rotation  L80
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R23
# x =  23  Current point now = 23  increment = 0
#
# Current point  23  Rotation  R77
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L2
# x =  98  Current point now = 98  increment = 0
#
# Current point  98  Rotation  R106
# x =  204  Current point now = 4  increment = 2
#
# Current point  4  Rotation  R96
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L621
# x =  -521  Current point now = 79  increment = 6
#
# Current point  79  Rotation  R24
# x =  103  Current point now = 3  increment = 1
#
# Current point  3  Rotation  L3
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R29
# x =  29  Current point now = 29  increment = 0
#
# Current point  29  Rotation  L266
# x =  -237  Current point now = 63  increment = 3
#
# Current point  63  Rotation  L63
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L40
# x =  60  Current point now = 60  increment = 0
#
# Current point  60  Rotation  R40
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L78
# ...
# x =  73  Current point now = 73  increment = 0
#
# Current point  73  Rotation  R426
# x =  499  Current point now = 99  increment = 4
#
# Current point  99  Rotation  L11
# x =  88  Current point now = 88  increment = 0
#
# Current point  88  Rotation  L43
# x =  45  Current point now = 45  increment = 0
#
# Current point  45  Rotation  L16
# x =  29  Current point now = 29  increment = 0
#
# Current point  29  Rotation  L64
# x =  -35  Current point now = 65  increment = 1
#
# Current point  65  Rotation  L65
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L747
# x =  -647  Current point now = 53  increment = 7
#
# Current point  53  Rotation  R22
# x =  75  Current point now = 75  increment = 0
#
# Current point  75  Rotation  L58
# x =  17  Current point now = 17  increment = 0
#
# Current point  17  Rotation  L64
# x =  -47  Current point now = 53  increment = 1
#
# Current point  53  Rotation  L53
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R77
# x =  77  Current point now = 77  increment = 0
#
# Current point  77  Rotation  L824
# x =  -747  Current point now = 53  increment = 8
#
# Current point  53  Rotation  R47
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L827
# x =  -727  Current point now = 73  increment = 8
#
# Current point  73  Rotation  R527
# x =  600  Current point now = 0  increment = 7
#
# Current point  0  Rotation  R13
# x =  13  Current point now = 13  increment = 0
#
# Current point  13  Rotation  L99
# x =  -86  Current point now = 14  increment = 1
#
# Current point  14  Rotation  L14
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R33
# x =  33  Current point now = 33  increment = 0
#
# Current point  33  Rotation  L45
# x =  -12  Current point now = 88  increment = 1
#
# Current point  88  Rotation  R92
# x =  180  Current point now = 80  increment = 1
#
# Current point  80  Rotation  R20
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L559
# x =  -459  Current point now = 41  increment = 5
#
# Current point  41  Rotation  L53
# x =  -12  Current point now = 88  increment = 1
#
# Current point  88  Rotation  R12
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L82
# x =  18  Current point now = 18  increment = 0
#
# Current point  18  Rotation  L18
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L55
# x =  45  Current point now = 45  increment = 0
#
# Current point  45  Rotation  R4
# x =  49  Current point now = 49  increment = 0
#
# Current point  49  Rotation  R851
# x =  900  Current point now = 0  increment = 10
#
# Current point  0  Rotation  R73
# x =  73  Current point now = 73  increment = 0
#
# Current point  73  Rotation  R69
# x =  142  Current point now = 42  increment = 1
#
# Current point  42  Rotation  L42
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R63
# x =  63  Current point now = 63  increment = 0
#
# Current point  63  Rotation  R8
# x =  71  Current point now = 71  increment = 0
#
# Current point  71  Rotation  R29
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R23
# x =  23  Current point now = 23  increment = 0
#
# Current point  23  Rotation  L1
# x =  22  Current point now = 22  increment = 0
#
# Current point  22  Rotation  R31
# x =  53  Current point now = 53  increment = 0
#
# Current point  53  Rotation  R57
# x =  110  Current point now = 10  increment = 1
#
# Current point  10  Rotation  L97
# x =  -87  Current point now = 13  increment = 1
#
# Current point  13  Rotation  L13
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R743
# x =  743  Current point now = 43  increment = 7
#
# Current point  43  Rotation  R57
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L277
# x =  -177  Current point now = 23  increment = 2
#
# Current point  23  Rotation  R61
# x =  84  Current point now = 84  increment = 0
#
# Current point  84  Rotation  L69
# x =  15  Current point now = 15  increment = 0
#
# Current point  15  Rotation  R923
# x =  938  Current point now = 38  increment = 9
#
# Current point  38  Rotation  R88
# x =  126  Current point now = 26  increment = 1
#
# Current point  26  Rotation  R9
# x =  35  Current point now = 35  increment = 0
#
# Current point  35  Rotation  R65
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R18
# x =  18  Current point now = 18  increment = 0
#
# Current point  18  Rotation  L18
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R16
# x =  16  Current point now = 16  increment = 0
#
# Current point  16  Rotation  L194
# x =  -178  Current point now = 22  increment = 2
#
# Current point  22  Rotation  L63
# x =  -41  Current point now = 59  increment = 1
#
# Current point  59  Rotation  L73
# x =  -14  Current point now = 86  increment = 1
#
# Current point  86  Rotation  L74
# x =  12  Current point now = 12  increment = 0
#
# Current point  12  Rotation  L480
# x =  -468  Current point now = 32  increment = 5
#
# Current point  32  Rotation  L32
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R18
# x =  18  Current point now = 18  increment = 0
#
# Current point  18  Rotation  L53
# x =  -35  Current point now = 65  increment = 1
#
# Current point  65  Rotation  R39
# x =  104  Current point now = 4  increment = 1
#
# Current point  4  Rotation  L404
# x =  -400  Current point now = 0  increment = 5
#
# Current point  0  Rotation  R381
# x =  381  Current point now = 81  increment = 3
#
# Current point  81  Rotation  R6
# x =  87  Current point now = 87  increment = 0
#
# Current point  87  Rotation  R13
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L71
# x =  29  Current point now = 29  increment = 0
#
# Current point  29  Rotation  R76
# x =  105  Current point now = 5  increment = 1
#
# Current point  5  Rotation  R42
# x =  47  Current point now = 47  increment = 0
#
# Current point  47  Rotation  R16
# x =  63  Current point now = 63  increment = 0
#
# Current point  63  Rotation  L63
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R210
# x =  210  Current point now = 10  increment = 2
#
# Current point  10  Rotation  L10
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L75
# x =  25  Current point now = 25  increment = 0
#
# Current point  25  Rotation  R49
# x =  74  Current point now = 74  increment = 0
#
# Current point  74  Rotation  L74
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R54
# x =  54  Current point now = 54  increment = 0
#
# Current point  54  Rotation  R22
# x =  76  Current point now = 76  increment = 0
#
# Current point  76  Rotation  L50
# x =  26  Current point now = 26  increment = 0
#
# Current point  26  Rotation  L21
# x =  5  Current point now = 5  increment = 0
#
# Current point  5  Rotation  R143
# x =  148  Current point now = 48  increment = 1
#
# Current point  48  Rotation  R108
# x =  156  Current point now = 56  increment = 1
#
# Current point  56  Rotation  R21
# x =  77  Current point now = 77  increment = 0
#
# Current point  77  Rotation  L77
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L81
# x =  19  Current point now = 19  increment = 0
#
# Current point  19  Rotation  R281
# x =  300  Current point now = 0  increment = 4
#
# Current point  0  Rotation  R23
# x =  23  Current point now = 23  increment = 0
#
# Current point  23  Rotation  R87
# x =  110  Current point now = 10  increment = 1
#
# Current point  10  Rotation  L75
# x =  -65  Current point now = 35  increment = 1
#
# Current point  35  Rotation  L52
# x =  -17  Current point now = 83  increment = 1
#
# Current point  83  Rotation  R51
# x =  134  Current point now = 34  increment = 1
#
# Current point  34  Rotation  R22
# x =  56  Current point now = 56  increment = 0
#
# Current point  56  Rotation  L51
# x =  5  Current point now = 5  increment = 0
#
# Current point  5  Rotation  L82
# x =  -77  Current point now = 23  increment = 1
#
# Current point  23  Rotation  L23
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  R10
# x =  10  Current point now = 10  increment = 0
#
# Current point  10  Rotation  L29
# x =  -19  Current point now = 81  increment = 1
#
# Current point  81  Rotation  R22
# x =  103  Current point now = 3  increment = 1
#
# Current point  3  Rotation  R97
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L1
# x =  99  Current point now = 99  increment = 0
#
# Current point  99  Rotation  L97
# x =  2  Current point now = 2  increment = 0
#
# Current point  2  Rotation  R44
# x =  46  Current point now = 46  increment = 0
#
# Current point  46  Rotation  L39
# x =  7  Current point now = 7  increment = 0
#
# Current point  7  Rotation  R1
# x =  8  Current point now = 8  increment = 0
#
# Current point  8  Rotation  L46
# x =  -38  Current point now = 62  increment = 1
#
# Current point  62  Rotation  L62
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L90
# x =  10  Current point now = 10  increment = 0
#
# Current point  10  Rotation  R66
# x =  76  Current point now = 76  increment = 0
#
# Current point  76  Rotation  R24
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R50
# x =  50  Current point now = 50  increment = 0
#
# Current point  50  Rotation  R96
# x =  146  Current point now = 46  increment = 1
#
# Current point  46  Rotation  R68
# x =  114  Current point now = 14  increment = 1
#
# Current point  14  Rotation  L9
# x =  5  Current point now = 5  increment = 0
#
# Current point  5  Rotation  R95
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L62
# x =  38  Current point now = 38  increment = 0
#
# Current point  38  Rotation  L25
# x =  13  Current point now = 13  increment = 0
#
# Current point  13  Rotation  L49
# x =  -36  Current point now = 64  increment = 1
#
# Current point  64  Rotation  L56
# x =  8  Current point now = 8  increment = 0
#
# Current point  8  Rotation  L82
# x =  -74  Current point now = 26  increment = 1
#
# Current point  26  Rotation  R30
# x =  56  Current point now = 56  increment = 0
#
# Current point  56  Rotation  L65
# x =  -9  Current point now = 91  increment = 1
#
# Current point  91  Rotation  L81
# x =  10  Current point now = 10  increment = 0
#
# Current point  10  Rotation  L10
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L73
# x =  27  Current point now = 27  increment = 0
#
# Current point  27  Rotation  L62
# x =  -35  Current point now = 65  increment = 1
#
# Current point  65  Rotation  L31
# x =  34  Current point now = 34  increment = 0
#
# Current point  34  Rotation  R66
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R97
# x =  97  Current point now = 97  increment = 0
#
# Current point  97  Rotation  R73
# x =  170  Current point now = 70  increment = 1
#
# Current point  70  Rotation  L61
# x =  9  Current point now = 9  increment = 0
#
# Current point  9  Rotation  R18
# x =  27  Current point now = 27  increment = 0
#
# Current point  27  Rotation  L94
# x =  -67  Current point now = 33  increment = 1
#
# Current point  33  Rotation  R81
# x =  114  Current point now = 14  increment = 1
#
# Current point  14  Rotation  R86
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  L74
# x =  26  Current point now = 26  increment = 0
#
# Current point  26  Rotation  R31
# x =  57  Current point now = 57  increment = 0
#
# Current point  57  Rotation  L57
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L62
# x =  38  Current point now = 38  increment = 0
#
# Current point  38  Rotation  L38
# x =  0  Current point now = 0  increment = 1
#
# Current point  0  Rotation  L74
# x =  26  Current point now = 26  increment = 0
#
# Current point  26  Rotation  R74
# x =  100  Current point now = 0  increment = 2
#
# Current point  0  Rotation  R33
# x =  33  Current point now = 33  increment = 0
#
# Current point  33  Rotation  R5
# x =  38  Current point now = 38  increment = 0
#
# Current point  38  Rotation  L1
# x =  37  Current point now = 37  increment = 0
#
# Current point  37  Rotation  R50
# x =  87  Current point now = 87  increment = 0
#
# Current point  87  Rotation  R47
# x =  134  Current point now = 34  increment = 1
#
# Current point  34  Rotation  R41
# x =  75  Current point now = 75  increment = 0
#
# Current point  75  Rotation  R35
# x =  110  Current point now = 10  increment = 1
#
# Current point  10  Rotation  L3
# x =  7  Current point now = 7  increment = 0
#
# Current point  7  Rotation  R38
# x =  45  Current point now = 45  increment = 0
#
# Current point  45  Rotation  R41
# x =  86  Current point now = 86  increment = 0
#
# Current point  86  Rotation  L39
# x =  47  Current point now = 47  increment = 0
#
# Current point  47  Rotation  L27
# x =  20  Current point now = 20  increment = 0
#
# Current point  20  Rotation  R48
# x =  68  Current point now = 68  increment = 0
#
# Current point  68  Rotation  L40
# x =  28  Current point now = 28  increment = 0
#
# Current point  28  Rotation  R4
# x =  32  Current point now = 32  increment = 0
#
# Current point  32  Rotation  R31
# x =  63  Current point now = 63  increment = 0
#
# Current point  63  Rotation  R48
# x =  111  Current point now = 11  increment = 1
#
# Current point  11  Rotation  R12
# x =  23  Current point now = 23  increment = 0
#
# Current point  23  Rotation  L45
# x =  -22  Current point now = 78  increment = 1
#
# Current point  78  Rotation  L27
# x =  51  Current point now = 51  increment = 0
#
# Current point  51  Rotation  L26
# x =  25  Current point now = 25  increment = 0
#
# Current point  25  Rotation  R38
# x =  63  Current point now = 63  increment = 0
#
# Current point  63  Rotation  L43
# x =  20  Current point now = 20  increment = 0
#
# Current point  20  Rotation  R23
# x =  43  Current point now = 43  increment = 0
#
# Current point  43  Rotation  R12
# x =  55  Current point now = 55  increment = 0
#
# Current point  55  Rotation  L21
# x =  34  Current point now = 34  increment = 0
#
# Current point  34  Rotation  R34
# x =  68  Current point now = 68  increment = 0
#
# Current point  68  Rotation  L18
# x =  50  Current point now = 50  increment = 0
#
# Current point  50  Rotation  R10
# x =  60  Current point now = 60  increment = 0
#
# Current point  60  Rotation  R20
# x =  80  Current point now = 80  increment = 0
#
# Current point  80  Rotation  L7
# x =  73  Current point now = 73  increment = 0
#
# Current point  73  Rotation  L16
# x =  57  Current point now = 57  increment = 0
#
# Current point  57  Rotation  L43
# x =  14  Current point now = 14  increment = 0
#
# Current point  14  Rotation  L19
# x =  -5  Current point now = 95  increment = 1
#
# Current point  95  Rotation  L1
# x =  94  Current point now = 94  increment = 0
#
# Current point  94  Rotation  L42
# x =  52  Current point now = 52  increment = 0
#
# Current point  52  Rotation  L50
# x =  2  Current point now = 2  increment = 0
#
# Current point  2  Rotation  L3
# x =  -1  Current point now = 99  increment = 1
#
# Current point  99  Rotation  L33
# x =  66  Current point now = 66  increment = 0
#
# Current point  66  Rotation  L39
# x =  27  Current point now = 27  increment = 0
#
# Current point  27  Rotation  L2
# x =  25  Current point now = 25  increment = 0
#
# Current point  25  Rotation  L32
# x =  -7  Current point now = 93  increment = 1
#
# Current point  93  Rotation  L36
# x =  57  Current point now = 57  increment = 0
#
# Current point  57  Rotation  R33
# x =  90  Current point now = 90  increment = 0
#
# Current point  90  Rotation  L5
# x =  85  Current point now = 85  increment = 0
#
# Current point  85  Rotation  L12
# x =  73  Current point now = 73  increment = 0
#
# Current point  73  Rotation  R2
# x =  75  Current point now = 75  increment = 0
#
# Current point  75  Rotation  L14
# x =  61  Current point now = 61  increment = 0
#
# Current point  61  Rotation  R10
# x =  71  Current point now = 71  increment = 0
#
# Current point  71  Rotation  L13
# x =  58  Current point now = 58  increment = 0
#
# Current point  58  Rotation  L35
# x =  23  Current point now = 23  increment = 0
#
# Current point  23  Rotation  R47
# x =  70  Current point now = 70  increment = 0
# 7239
